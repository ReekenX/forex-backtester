# %% [markdown]
# # 1M Confirmation Candle Analysis
#
# Analyzes trade alignment with EMA(50), EMA(200), and engulfing candle patterns.
#
# Key questions:
# - Does aligning with EMA(50) or EMA(200) improve win rate?
# - Is trading against EMAs profitable?
# - What SL range works best with each EMA alignment?
# - Does it matter if both EMAs agree?
# - Are engulfing candles more profitable than non-engulfing?
# - Do engulfing candles combined with EMA alignment provide an edge?

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils.confirmation_candle import load_data, display_analysis

# Load data
df = load_data()

# Disable scrolling
HTML('<style>.jp-OutputArea { max-height: none !important; }</style>')
# Out:
# <style>.jp-OutputArea { max-height: none !important; }</style>

# %%
# Display analysis
display_analysis(df)
# Out:
# <style>
#         .jp-OutputArea-child { max-height: none !important; }
#         .jp-OutputArea-output { max-height: none !important; overflow: visible !important; }
#         .output_scroll { box-shadow: none !important; border: none !important; }
#     </style>
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>1M Confirmation Candle Analysis (1:1 & 1:2 RRR)</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th class="strategy-col">Strategy</th><th>Buffer</th><th>RRR</th><th>Trades (194)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (37)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 4</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>20W – 24L</td>
#                 <td>45.5%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">12.1%</td>
#                 <td>16</td>
#                 <td>59%</td>
#                 <td>2.8</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 5</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>22W – 28L</td>
#                 <td>44.0%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">10.7%</td>
#                 <td>17</td>
#                 <td>59%</td>
#                 <td>3.1</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>32</td>
#                 <td>14W – 18L</td>
#                 <td>43.8%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.4%</td>
#                 <td>11</td>
#                 <td>48%</td>
#                 <td>3.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 3</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>32</td>
#                 <td>14W – 18L</td>
#                 <td>43.8%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.4%</td>
#                 <td>11</td>
#                 <td>48%</td>
#                 <td>3.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 3</td>
#                 <td>+0.5</td>
#                 <td>1:2</td>
#                 <td>32</td>
#                 <td>14W – 18L</td>
#                 <td>43.8%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.4%</td>
#                 <td>12</td>
#                 <td>52%</td>
#                 <td>3.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes or Similar + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>37</td>
#                 <td>16W – 21L</td>
#                 <td>43.2%</td>
#                 <td>11R</td>
#                 <td class="positive-edge">9.9%</td>
#                 <td>12</td>
#                 <td>48%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes or Similar + SL < 3</td>
#                 <td>+0.5</td>
#                 <td>1:2</td>
#                 <td>37</td>
#                 <td>16W – 21L</td>
#                 <td>43.2%</td>
#                 <td>11R</td>
#                 <td class="positive-edge">9.9%</td>
#                 <td>13</td>
#                 <td>52%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 4</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>15</td>
#                 <td>56%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>15</td>
#                 <td>56%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 4</td>
#                 <td>+0.5</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>15</td>
#                 <td>56%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes or Similar + SL < 4</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>18</td>
#                 <td>60%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes or Similar + SL < 4</td>
#                 <td>+0.5</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>17</td>
#                 <td>57%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes or Similar + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>17</td>
#                 <td>57%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>49</td>
#                 <td>21W – 28L</td>
#                 <td>42.9%</td>
#                 <td>14R</td>
#                 <td class="positive-edge">9.5%</td>
#                 <td>17</td>
#                 <td>65%</td>
#                 <td>3.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>49</td>
#                 <td>21W – 28L</td>
#                 <td>42.9%</td>
#                 <td>14R</td>
#                 <td class="positive-edge">9.5%</td>
#                 <td>17</td>
#                 <td>65%</td>
#                 <td>3.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>49</td>
#                 <td>29W – 20L</td>
#                 <td>59.2%</td>
#                 <td>9R</td>
#                 <td class="positive-edge">9.2
