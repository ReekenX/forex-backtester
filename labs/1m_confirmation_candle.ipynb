# %% [markdown]
# # 1M Confirmation Candle Analysis
#
# Analyzes trade alignment with EMA(50), EMA(200), and engulfing candle patterns.
#
# Key questions:
# - Does aligning with EMA(50) or EMA(200) improve win rate?
# - Is trading against EMAs profitable?
# - What SL range works best with each EMA alignment?
# - Does it matter if both EMAs agree?
# - Are engulfing candles more profitable than non-engulfing?
# - Do engulfing candles combined with EMA alignment provide an edge?

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils.confirmation_candle import load_data, display_analysis, display_bruteforce, display_limit_order

# Load data
df = load_data()

# Disable scrolling
HTML('<style>.jp-OutputArea { max-height: none !important; }</style>')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.jp-OutputArea { max-height: none !important; }</style>

# %%
# Display analysis
display_analysis(df)
# Out:
# <style>
#         .jp-OutputArea-child { max-height: none !important; }
#         .jp-OutputArea-output { max-height: none !important; overflow: visible !important; }
#         .output_scroll { box-shadow: none !important; border: none !important; }
#     </style>
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>1M Confirmation Candle Analysis</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th class="strategy-col">Strategy</th><th>Buffer</th><th>RRR</th><th>Trades (214)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (42)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>22W – 28L</td>
#                 <td>44.0%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">10.7%</td>
#                 <td>18</td>
#                 <td>67%</td>
#                 <td>3.1</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>22W – 28L</td>
#                 <td>44.0%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">10.7%</td>
#                 <td>18</td>
#                 <td>67%</td>
#                 <td>3.1</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>50</td>
#                 <td>30W – 20L</td>
#                 <td>60.0%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.0%</td>
#                 <td>21</td>
#                 <td>78%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>50</td>
#                 <td>30W – 20L</td>
#                 <td>60.0%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.0%</td>
#                 <td>21</td>
#                 <td>78%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>50</td>
#                 <td>30W – 20L</td>
#                 <td>60.0%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.0%</td>
#                 <td>21</td>
#                 <td>78%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>50</td>
#                 <td>30W – 20L</td>
#                 <td>60.0%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">10.0%</td>
#                 <td>21</td>
#                 <td>78%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>58</td>
#                 <td>25W – 33L</td>
#                 <td>43.1%</td>
#                 <td>17R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>20</td>
#                 <td>71%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>58</td>
#                 <td>25W – 33L</td>
#                 <td>43.1%</td>
#                 <td>17R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>20</td>
#                 <td>71%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>68</td>
#                 <td>29W – 39L</td>
#                 <td>42.6%</td>
#                 <td>19R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>22</td>
#                 <td>73%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>68</td>
#                 <td>29W – 39L</td>
#                 <td>42.6%</td>
#                 <td>19R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>22</td>
#                 <td>73%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 4</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>47</td>
#                 <td>20W – 27L</td>
#                 <td>42.6%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.2%</td>
#                 <td>16</td>
#                 <td>53%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>21W – 29L</td>
#                 <td>42.0%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">8.7%</td>
#                 <td>17</td>
#                 <td>63%</td>
#                 <td>3.8</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>21W – 29L</td>
#                 <td>42.0%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">8.7%</td>
#                 <td>17</td>
#                 <td>63%</td>
#                 <td>3.8</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>21W – 29L</td>
#                 <td>42.0%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">8.7%</td>
#                 <td>16</td>
#                 <td>59%</td>
#                 <td>3.8</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>50</td>
#                 <td>21W – 29L</td>
#                 <td>42.0%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">8.7%</td>
#                 <td>16</td>
#                 <td>59%</td>
#                 <td>3.8</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 5</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>60</td>
#                 <td>25W – 35L</td>
#                 <td>41.7%</td>
#                 <td>15R</td>

# %%
# Bruteforce: scan all buffer × RRR combinations
display_bruteforce(df)
# Out:
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>Bruteforce: Buffer × RRR Scan (All Trades)</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th>Buffer</th><th>RRR</th><th>Trades (214)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (42)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>214</td>
#                 <td>76W – 138L</td>
#                 <td>35.5%</td>
#                 <td>14R</td>
#                 <td class="positive-edge">2.2%</td>
#                 <td>35</td>
#                 <td>83%</td>
#                 <td>15.3</td>
#             </tr>
#             <tr>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>214</td>
#                 <td>75W – 139L</td>
#                 <td>35.0%</td>
#                 <td>11R</td>
#                 <td class="positive-edge">1.7%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>19.5</td>
#             </tr>
#             <tr>
#                 <td>+0.5</td>
#                 <td>1:3</td>
#                 <td>214</td>
#                 <td>56W – 158L</td>
#                 <td>26.2%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">1.2%</td>
#                 <td>32</td>
#                 <td>76%</td>
#                 <td>21.4</td>
#             </tr>
#             <tr>
#                 <td>+1.0</td>
#                 <td>1:3</td>
#                 <td>214</td>
#                 <td>54W – 160L</td>
#                 <td>25.2%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">0.2%</td>
#                 <td>29</td>
#                 <td>69%</td>
#                 <td>107.0</td>
#             </tr>
#             <tr>
#                 <td>+1.0</td>
#                 <td>1:2</td>
#                 <td>214</td>
#                 <td>71W – 143L</td>
#                 <td>33.2%</td>
#                 <td>-1R</td>
#                 <td class="negative-edge">-0.2%</td>
#                 <td>34</td>
#                 <td>81%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+0.0</td>
#                 <td>1:3</td>
#                 <td>214</td>
#                 <td>53W – 161L</td>
#                 <td>24.8%</td>
#                 <td>-2R</td>
#                 <td class="negative-edge">-0.2%</td>
#                 <td>33</td>
#                 <td>79%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+2.5</td>
#                 <td>1:2</td>
#                 <td>214</td>
#                 <td>70W – 144L</td>
#                 <td>32.7%</td>
#                 <td>-4R</td>
#                 <td class="negative-edge">-0.6%</td>
#                 <td>34</td>
#                 <td>81%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+1.5</td>
#                 <td>1:3</td>
#                 <td>214</td>
#                 <td>52W – 162L</td>
#                 <td>24.3%</td>
#                 <td>-6R</td>
#                 <td class="negative-edge">-0.7%</td>
#                 <td>29</td>
#                 <td>69%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>104W – 110L</td>
#                 <td>48.6%</td>
#                 <td>-6R</td>
#                 <td class="negative-edge">-1.4%</td>
#                 <td>38</td>
#                 <td>90%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>214</td>
#                 <td>69W – 145L</td>
#                 <td>32.2%</td>
#                 <td>-7R</td>
#                 <td class="negative-edge">-1.1%</td>
#                 <td>33</td>
#                 <td>79%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+4.5</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>101W – 113L</td>
#                 <td>47.2%</td>
#                 <td>-12R</td>
#                 <td class="negative-edge">-2.8%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+0.5</td>
#                 <td>1:2</td>
#                 <td>214</td>
#                 <td>66W – 148L</td>
#                 <td>30.8%</td>
#                 <td>-16R</td>
#                 <td class="negative-edge">-2.5%</td>
#                 <td>33</td>
#                 <td>79%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+3.0</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>99W – 115L</td>
#                 <td>46.3%</td>
#                 <td>-16R</td>
#                 <td class="negative-edge">-3.7%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+3.5</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>99W – 115L</td>
#                 <td>46.3%</td>
#                 <td>-16R</td>
#                 <td class="negative-edge">-3.7%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>99W – 115L</td>
#                 <td>46.3%</td>
#                 <td>-16R</td>
#                 <td class="negative-edge">-3.7%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+5.5</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>99W – 115L</td>
#                 <td>46.3%</td>
#                 <td>-16R</td>
#                 <td class="negative-edge">-3.7%</td>
#                 <td>38</td>
#                 <td>90%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+2.5</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>95W – 119L</td>
#                 <td>44.4%</td>
#                 <td>-24R</td>
#                 <td class="negative-edge">-5.6%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+6.0</td>
#                 <td>1:1</td>
#                 <td>214</td>
#                 <td>94W – 120L</td>
#                 <td>43.9%</td>
#                 <td>-26R</td>
#                 <td class="negative-edge">-6.1%</td>
#                 <td>37</td>
#                 <td>88%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td>+2.0</td>
#                 <td>1:3</td>
#                 <td>214</td>
#                 <td>46W – 168L</td>
#                 <td>21.5%</td>
#                 <td>-30R</td>
#                 <td class="negative-edge">-3.5%</td>
#                 <td>30</td>
#                 <td>71%</td>
#                 <td>N/A</td>
#             </tr>

# %%
# Limit order at half SL price
display_limit_order(df)
# Out:
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>Limit Order at Half SL Price</h2><p style='color: #a0a0a0; background-color: #1e1e1e; padding: 0 10px 10px;'>Entry at SL/2 pullback. New SL = SL/2, New TP = TP + SL/2. Only trades with SL &ge; 2.2 (broker min 1.1 pip).</p>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th class="strategy-col">Strategy</th><th>RRR</th><th>Trades (214)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (42)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>10</td>
#                 <td>7W – 3L</td>
#                 <td>70.0%</td>
#                 <td>11R</td>
#                 <td class="positive-edge">36.7%</td>
#                 <td>7</td>
#                 <td>70%</td>
#                 <td>0.9</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>9</td>
#                 <td>6W – 3L</td>
#                 <td>66.7%</td>
#                 <td>9R</td>
#                 <td class="positive-edge">33.3%</td>
#                 <td>6</td>
#                 <td>67%</td>
#                 <td>1.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>9</td>
#                 <td>6W – 3L</td>
#                 <td>66.7%</td>
#                 <td>9R</td>
#                 <td class="positive-edge">33.3%</td>
#                 <td>6</td>
#                 <td>67%</td>
#                 <td>1.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(50) Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>11</td>
#                 <td>6W – 5L</td>
#                 <td>54.5%</td>
#                 <td>7R</td>
#                 <td class="positive-edge">21.2%</td>
#                 <td>6</td>
#                 <td>60%</td>
#                 <td>1.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 3</td>
#                 <td>1:1</td>
#                 <td>10</td>
#                 <td>7W – 3L</td>
#                 <td>70.0%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">20.0%</td>
#                 <td>7</td>
#                 <td>70%</td>
#                 <td>2.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>1:1</td>
#                 <td>9</td>
#                 <td>6W – 3L</td>
#                 <td>66.7%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">16.7%</td>
#                 <td>6</td>
#                 <td>67%</td>
#                 <td>3.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>1:1</td>
#                 <td>9</td>
#                 <td>6W – 3L</td>
#                 <td>66.7%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">16.7%</td>
#                 <td>6</td>
#                 <td>67%</td>
#                 <td>3.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>15</td>
#                 <td>7W – 8L</td>
#                 <td>46.7%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">13.3%</td>
#                 <td>7</td>
#                 <td>54%</td>
#                 <td>2.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>15</td>
#                 <td>7W – 8L</td>
#                 <td>46.7%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">13.3%</td>
#                 <td>7</td>
#                 <td>54%</td>
#                 <td>2.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: No + SL < 3</td>
#                 <td>1:2</td>
#                 <td>9</td>
#                 <td>4W – 5L</td>
#                 <td>44.4%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">11.1%</td>
#                 <td>4</td>
#                 <td>44%</td>
#                 <td>3.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(50) Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>21</td>
#                 <td>9W – 12L</td>
#                 <td>42.9%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">9.5%</td>
#                 <td>9</td>
#                 <td>50%</td>
#                 <td>3.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>19</td>
#                 <td>8W – 11L</td>
#                 <td>42.1%</td>
#                 <td>5R</td>
#                 <td class="positive-edge">8.8%</td>
#                 <td>8</td>
#                 <td>47%</td>
#                 <td>3.8</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 5</td>
#                 <td>1:2</td>
#                 <td>17</td>
#                 <td>7W – 10L</td>
#                 <td>41.2%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">7.8%</td>
#                 <td>7</td>
#                 <td>50%</td>
#                 <td>4.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 5</td>
#                 <td>1:2</td>
#                 <td>17</td>
#                 <td>7W – 10L</td>
#                 <td>41.2%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">7.8%</td>
#                 <td>7</td>
#                 <td>50%</td>
#                 <td>4.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 3</td>
#                 <td>1:2</td>
#                 <td>10</td>
#                 <td>4W – 6L</td>
#                 <td>40.0%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>4</td>
#                 <td>44%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Has Engulfing Data + SL < 3</td>
#                 <td>1:2</td>
#                 <td>20</td>
#                 <td>8W – 12L</td>
#                 <td>40.0%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>8</td>
#                 <td>47%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">All Trades + SL < 3</td>
#                 <td>1:2</td>
#                 <td>20</td>
#                 <td>8W – 12L</td>
#                 <td>40.0%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>8</td>
#                 <td>47%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col
