# %% [markdown]
# # 1M Confirmation Candle Analysis
#
# Analyzes trade alignment with 1H (higher timeframe) direction.
#
# 1H column represents higher timeframe alignment:
# - **Buy**: trade idea is above High or bounced from Low
# - **Sell**: trade idea is below Low or bounced from High
#
# Key questions:
# - Does aligning with 1H direction improve win rate?
# - Is trading against 1H direction profitable?
# - What SL range works best with 1H alignment?

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils.confirmation_candle import (
    load_data, display_analysis, display_bruteforce, display_limit_order,
    display_r_histogram, display_r_histogram_combined,
)

# Load data
df = load_data()

# Disable scrolling
HTML('<style>.jp-OutputArea { max-height: none !important; }</style>')

# %%
# R value distribution histogram (1R–10R, absolute values)
display_r_histogram(df)
# Out:
#     <div style="background-color: #1e1e1e; padding: 20px; font-family: 'Courier New', monospace;">
#         <h2 style="color: #e0e0e0; margin-top: 0;">R Distribution (1R - 10R)</h2>
#
#         <div style="display: flex; align-items: center; margin: 4px 0;">
#             <span style="color: #e0e0e0; width: 40px; text-align: right; margin-right: 10px;">1R</span>
#             <div style="background-color: #4ade80; height: 24px; width: 20.51282051282051%; min-width: 2px; border-radius: 3px;"></div>
#             <span style="color: #a0a0a0; margin-left: 8px;">8</span>
#         </div>
#
#         <div style="display: flex; align-items: center; margin: 4px 0;">
#             <span style="color: #e0e0e0; width: 40px; text-align: right; margin-right: 10px;">2R</span>
#             <div style="background-color: #4ade80; height: 24px; width: 48.717948717948715%; min-width: 2px; border-radius: 3px;"></div>
#             <span style="color: #a0a0a0; margin-left: 8px;">19</span>
# ...

# %%
# R value distribution histogram combined (cumulative, 1R–10R)
display_r_histogram_combined(df)

# %%
# Display analysis
display_analysis(df)
# Out:
# <style>
#         .jp-OutputArea-child { max-height: none !important; }
#         .jp-OutputArea-output { max-height: none !important; overflow: visible !important; }
#         .output_scroll { box-shadow: none !important; border: none !important; }
#     </style>
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>1M Confirmation Candle Analysis</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
# ...

# %%
# Bruteforce: scan all buffer × RRR combinations
display_bruteforce(df)
# Out:
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>Bruteforce: Buffer x RRR Scan (All Trades)</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
# ...

# %%
# Limit order at half SL price
display_limit_order(df)
# Out:
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>Limit Order at Half SL Price</h2><p style='color: #a0a0a0; background-color: #1e1e1e; padding: 0 10px 10px;'>Entry at SL/2 pullback. New SL = SL/2, New TP = TP + SL/2. Only trades with SL &ge; 2.2 (broker min 1.1 pip).</p>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
# ...
