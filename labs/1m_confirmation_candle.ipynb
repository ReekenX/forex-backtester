# %% [markdown]
# # 1M Confirmation Candle Analysis
#
# Analyzes trade alignment with EMA(50), EMA(200), and engulfing candle patterns at **1:1 and 1:2 RRR**.
#
# Key questions:
# - Does aligning with EMA(50) or EMA(200) improve win rate?
# - Is trading against EMAs profitable?
# - What SL range works best with each EMA alignment?
# - Does it matter if both EMAs agree?
# - Are engulfing candles more profitable than non-engulfing?
# - Do engulfing candles combined with EMA alignment provide an edge?

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils.confirmation_candle import load_data, display_analysis

# Load data
df = load_data()

# Disable scrolling
HTML('<style>.jp-OutputArea { max-height: none !important; }</style>')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.jp-OutputArea { max-height: none !important; }</style>

# %%
# Display analysis
display_analysis(df)
# Out:
# <style>
#         .jp-OutputArea-child { max-height: none !important; }
#         .jp-OutputArea-output { max-height: none !important; overflow: visible !important; }
#         .output_scroll { box-shadow: none !important; border: none !important; }
#     </style>
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>1M Confirmation Candle Analysis (1:1 & 1:2 RRR)</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th class="strategy-col">Strategy</th><th>Buffer</th><th>RRR</th><th>Trades (178)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (35)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>44</td>
#                 <td>27W – 17L</td>
#                 <td>61.4%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">11.4%</td>
#                 <td>18</td>
#                 <td>75%</td>
#                 <td>4.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>44</td>
#                 <td>27W – 17L</td>
#                 <td>61.4%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">11.4%</td>
#                 <td>18</td>
#                 <td>75%</td>
#                 <td>4.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>14</td>
#                 <td>58%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>15</td>
#                 <td>62%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>15</td>
#                 <td>62%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>44</td>
#                 <td>19W – 25L</td>
#                 <td>43.2%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>14</td>
#                 <td>58%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>16</td>
#                 <td>64%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>+3.0</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>16</td>
#                 <td>64%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>17</td>
#                 <td>68%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>51</td>
#                 <td>22W – 29L</td>
#                 <td>43.1%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.8%</td>
#                 <td>17</td>
#                 <td>68%</td>
#                 <td>3.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 4</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>73</td>
#                 <td>31W – 42L</td>
#                 <td>42.5%</td>
#                 <td>20R</td>
#                 <td class="positive-edge">9.1%</td>
#                 <td>21</td>
#                 <td>70%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>44</td>
#                 <td>26W – 18L</td>
#                 <td>59.1%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">9.1%</td>
#                 <td>18</td>
#                 <td>75%</td>
#                 <td>5.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>44</td>
#                 <td>26W – 18L</td>
#                 <td>59.1%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">9.1%</td>
#                 <td>18</td>
#                 <td>75%</td>
#                 <td>5.5</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>51</td>
#                 <td>30W – 21L</td>
#                 <td>58.8%</td>
#                 <td>9R</td>
#                 <td class="positive-edge">8.8%</td>
#                 <td>20</td>
#                 <td>80%</td>
#                 <td>5.7</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>51</td>
#                 <td>30W – 21L</td>
#                 <td>58.8%</td>
#                 <td>9R</td>
#                 <td class="positive-edge">8.8%</td>
#                 <td>20</td>
#                 <td>80%</td>
#                 <td>5.7</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 3</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>62</td>
#                 <td>26W – 36L</td>
#                 <td>41.9%</td>
#                 <td>16R</td>
