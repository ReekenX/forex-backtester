# %% [markdown]
# # 1M Confirmation Candle Analysis
#
# Analyzes trade alignment with EMA(50), EMA(200), and engulfing candle patterns.
#
# Key questions:
# - Does aligning with EMA(50) or EMA(200) improve win rate?
# - Is trading against EMAs profitable?
# - What SL range works best with each EMA alignment?
# - Does it matter if both EMAs agree?
# - Are engulfing candles more profitable than non-engulfing?
# - Do engulfing candles combined with EMA alignment provide an edge?

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils.confirmation_candle import (
    load_data, display_analysis, display_bruteforce, display_limit_order,
)

# Load data
df = load_data()

# Disable scrolling
HTML('<style>.jp-OutputArea { max-height: none !important; }</style>')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.jp-OutputArea { max-height: none !important; }</style>

# %%
# Display analysis
display_analysis(df)
# Out:
# <style>
#         .jp-OutputArea-child { max-height: none !important; }
#         .jp-OutputArea-output { max-height: none !important; overflow: visible !important; }
#         .output_scroll { box-shadow: none !important; border: none !important; }
#     </style>
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>1M Confirmation Candle Analysis</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th class="strategy-col">Strategy</th><th>Buffer</th><th>RRR</th><th>Trades (231)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (45)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>54</td>
#                 <td>23W – 31L</td>
#                 <td>42.6%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>19</td>
#                 <td>63%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>54</td>
#                 <td>23W – 31L</td>
#                 <td>42.6%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>19</td>
#                 <td>63%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:2</td>
#                 <td>54</td>
#                 <td>23W – 31L</td>
#                 <td>42.6%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>19</td>
#                 <td>63%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:2</td>
#                 <td>54</td>
#                 <td>23W – 31L</td>
#                 <td>42.6%</td>
#                 <td>15R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>19</td>
#                 <td>63%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>54</td>
#                 <td>32W – 22L</td>
#                 <td>59.3%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>23</td>
#                 <td>77%</td>
#                 <td>5.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>54</td>
#                 <td>32W – 22L</td>
#                 <td>59.3%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>23</td>
#                 <td>77%</td>
#                 <td>5.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>54</td>
#                 <td>32W – 22L</td>
#                 <td>59.3%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>23</td>
#                 <td>77%</td>
#                 <td>5.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>54</td>
#                 <td>32W – 22L</td>
#                 <td>59.3%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">9.3%</td>
#                 <td>23</td>
#                 <td>77%</td>
#                 <td>5.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 4</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>47</td>
#                 <td>20W – 27L</td>
#                 <td>42.6%</td>
#                 <td>13R</td>
#                 <td class="positive-edge">9.2%</td>
#                 <td>16</td>
#                 <td>53%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>73</td>
#                 <td>31W – 42L</td>
#                 <td>42.5%</td>
#                 <td>20R</td>
#                 <td class="positive-edge">9.1%</td>
#                 <td>24</td>
#                 <td>73%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>73</td>
#                 <td>31W – 42L</td>
#                 <td>42.5%</td>
#                 <td>20R</td>
#                 <td class="positive-edge">9.1%</td>
#                 <td>24</td>
#                 <td>73%</td>
#                 <td>3.6</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>62</td>
#                 <td>26W – 36L</td>
#                 <td>41.9%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">8.6%</td>
#                 <td>21</td>
#                 <td>68%</td>
#                 <td>3.9</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>62</td>
#                 <td>26W – 36L</td>
#                 <td>41.9%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">8.6%</td>
#                 <td>21</td>
#                 <td>68%</td>
#                 <td>3.9</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>+4.0</td>
#                 <td>1:2</td>
#                 <td>62</td>
#                 <td>26W – 36L</td>
#                 <td>41.9%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">8.6%</td>
#                 <td>22</td>
#                 <td>71%</td>
#                 <td>3.9</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>+4.0</td>
#                 <td>1:2</td>
#                 <td>62</td>
#                 <td>26W – 36L</td>
#                 <td>41.9%</td>
#                 <td>16R</td>
#                 <td class="positive-edge">8.6%</td>
#                 <td>22</td>
#                 <td>71%</td>
#                 <td>3.9</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 5</td>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>53</td>
#                 <td>22W – 31L</td>
#                 <td>41.5%</td>
#                 <td>13R</td>
#                 <td clas

# %%
# Bruteforce: scan all buffer × RRR combinations
display_bruteforce(df)
# Out:
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>Bruteforce: Buffer × RRR Scan (All Trades)</h2>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th>Buffer</th><th>RRR</th><th>Trades (231)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (45)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td>+1.5</td>
#                 <td>1:2</td>
#                 <td>231</td>
#                 <td>80W – 151L</td>
#                 <td>34.6%</td>
#                 <td>9R</td>
#                 <td class="positive-edge">1.3%</td>
#                 <td>37</td>
#                 <td>82%</td>
#                 <td>25.7</td>
#             </tr>
#             <tr>
#                 <td>+2.0</td>
#                 <td>1:2</td>
#                 <td>231</td>
#                 <td>79W – 152L</td>
#                 <td>34.2%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">0.9%</td>
#                 <td>39</td>
#                 <td>87%</td>
#                 <td>38.5</td>
#             </tr>
#             <tr>
#                 <td>+0.5</td>
#                 <td>1:3</td>
#                 <td>231</td>
#                 <td>59W – 172L</td>
#                 <td>25.5%</td>
#                 <td>5R</td>
#                 <td class="positive-edge">0.5%</td>
#                 <td>34</td>
#                 <td>76%</td>
#                 <td>46.2</td>
#             </tr>
#
#         </tbody>
#     </table>

# %%
# Limit order at half SL price
display_limit_order(df)
# Out:
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>Limit Order at Half SL Price</h2><p style='color: #a0a0a0; background-color: #1e1e1e; padding: 0 10px 10px;'>Entry at SL/2 pullback. New SL = SL/2, New TP = TP + SL/2. Only trades with SL &ge; 2.2 (broker min 1.1 pip).</p>
#     <style>
#         .analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="analysis-table">
#         <thead>
#             <tr>
#     <th class="strategy-col">Strategy</th><th>RRR</th><th>Trades (231)</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days (45)</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>11</td>
#                 <td>7W – 4L</td>
#                 <td>63.6%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">30.3%</td>
#                 <td>7</td>
#                 <td>64%</td>
#                 <td>1.1</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>10</td>
#                 <td>6W – 4L</td>
#                 <td>60.0%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">26.7%</td>
#                 <td>6</td>
#                 <td>60%</td>
#                 <td>1.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>10</td>
#                 <td>6W – 4L</td>
#                 <td>60.0%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">26.7%</td>
#                 <td>6</td>
#                 <td>60%</td>
#                 <td>1.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(50) Aligned + SL < 3</td>
#                 <td>1:2</td>
#                 <td>12</td>
#                 <td>6W – 6L</td>
#                 <td>50.0%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">16.7%</td>
#                 <td>6</td>
#                 <td>55%</td>
#                 <td>2.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 3</td>
#                 <td>1:1</td>
#                 <td>11</td>
#                 <td>7W – 4L</td>
#                 <td>63.6%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">13.6%</td>
#                 <td>7</td>
#                 <td>64%</td>
#                 <td>3.7</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>16</td>
#                 <td>7W – 9L</td>
#                 <td>43.8%</td>
#                 <td>5R</td>
#                 <td class="positive-edge">10.4%</td>
#                 <td>7</td>
#                 <td>50%</td>
#                 <td>3.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>16</td>
#                 <td>7W – 9L</td>
#                 <td>43.8%</td>
#                 <td>5R</td>
#                 <td class="positive-edge">10.4%</td>
#                 <td>7</td>
#                 <td>50%</td>
#                 <td>3.2</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 3</td>
#                 <td>1:1</td>
#                 <td>10</td>
#                 <td>6W – 4L</td>
#                 <td>60.0%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">10.0%</td>
#                 <td>6</td>
#                 <td>60%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 3</td>
#                 <td>1:1</td>
#                 <td>10</td>
#                 <td>6W – 4L</td>
#                 <td>60.0%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">10.0%</td>
#                 <td>6</td>
#                 <td>60%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(50) Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>22</td>
#                 <td>9W – 13L</td>
#                 <td>40.9%</td>
#                 <td>5R</td>
#                 <td class="positive-edge">7.6%</td>
#                 <td>9</td>
#                 <td>47%</td>
#                 <td>4.4</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: No + SL < 3</td>
#                 <td>1:2</td>
#                 <td>10</td>
#                 <td>4W – 6L</td>
#                 <td>40.0%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>4</td>
#                 <td>40%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Engulfing: Yes + SL < 3</td>
#                 <td>1:2</td>
#                 <td>10</td>
#                 <td>4W – 6L</td>
#                 <td>40.0%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>4</td>
#                 <td>44%</td>
#                 <td>5.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned + SL < 5</td>
#                 <td>1:2</td>
#                 <td>18</td>
#                 <td>7W – 11L</td>
#                 <td>38.9%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">5.6%</td>
#                 <td>7</td>
#                 <td>47%</td>
#                 <td>6.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMAs Agree + Direction Aligned + SL < 5</td>
#                 <td>1:2</td>
#                 <td>18</td>
#                 <td>7W – 11L</td>
#                 <td>38.9%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">5.6%</td>
#                 <td>7</td>
#                 <td>47%</td>
#                 <td>6.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Has Engulfing Data + SL < 3</td>
#                 <td>1:2</td>
#                 <td>21</td>
#                 <td>8W – 13L</td>
#                 <td>38.1%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">4.8%</td>
#                 <td>8</td>
#                 <td>44%</td>
#                 <td>7.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">EMA(200) Aligned + SL < 4</td>
#                 <td>1:2</td>
#                 <td>21</td>
#                 <td>8W – 13L</td>
#                 <td>38.1%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">4.8%</td>
#                 <td>8</td>
#                 <td>44%</td>
#                 <td>7.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-col">Both EMAs Aligned</td>
#                 <td>1:2</td>
#                 <td>24</td>
#                 <td>9W – 15L</td>
#                 <td>37.5%</td>
#                 <td>3R</td>
#                 <td class="positive-edge">4.2%</td>
#                 <td>8</td>
#                 <td>42%</td>
#                 <td>8.0</td>
#             </tr>
#             <tr>
#                 <td class="strategy-c
