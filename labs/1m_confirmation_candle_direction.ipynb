# %% [markdown]
# # 1M Confirmation Candle Direction Analysis
#
# Analyzes trade direction alignment with EMA(50) and EMA(200) at **1:1 RRR only**.
#
# Key questions:
# - Does aligning with EMA(50) or EMA(200) improve win rate?
# - Is trading against EMAs profitable?
# - What SL range works best with each EMA alignment?
# - Does it matter if both EMAs agree?

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils.direction import load_data, display_direction_analysis

# Load data
df = load_data()

# Display direction analysis
display_direction_analysis(df)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>
#         .jp-OutputArea-child { max-height: none !important; }
#         .jp-OutputArea-output { max-height: none !important; overflow: visible !important; }
#         .output_scroll { box-shadow: none !important; border: none !important; }
#     </style>
# <h2 style='color: #e0e0e0; background-color: #1e1e1e; padding: 10px;'>1M Confirmation Candle Direction Analysis (1:1 RRR)</h2>
#     <style>
#         .direction-analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             background-color: #1e1e1e;
#             color: #e0e0e0;
#             font-family: 'Courier New', monospace;
#             font-size: 12px;
#         }
#         .direction-analysis-table th {
#             background-color: #2d2d2d;
#             color: #e0e0e0;
#             padding: 8px;
#             text-align: left;
#             border: 1px solid #404040;
#             font-weight: bold;
#         }
#         .direction-analysis-table td {
#             padding: 6px 8px;
#             border: 1px solid #404040;
#         }
#         .direction-analysis-table tr:hover {
#             background-color: #2a2a2a;
#         }
#         .direction-strategy-col {
#             width: 300px;
#         }
#         .positive-edge {
#             color: #4ade80;
#         }
#         .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="direction-analysis-table">
#         <thead>
#             <tr>
#     <th class="direction-strategy-col">Strategy</th><th>Buffer</th><th>RRR</th><th>Trades</th><th>Notation</th><th>Win Rate</th><th>Outcome</th><th>Edge</th><th>Days</th><th>Days %</th><th>Trades Required</th>
#             </tr>
#         </thead>
#         <tbody>
#                 <tr>
#                 <td class="direction-strategy-col">Both EMAs Aligned</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>60</td>
#                 <td>34W – 26L</td>
#                 <td>56.7%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>21</td>
#                 <td>81%</td>
#                 <td>7.5</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMAs Agree + Direction Aligned</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>60</td>
#                 <td>34W – 26L</td>
#                 <td>56.7%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">6.7%</td>
#                 <td>21</td>
#                 <td>81%</td>
#                 <td>7.5</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMA(200) Aligned</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>86</td>
#                 <td>48W – 38L</td>
#                 <td>55.8%</td>
#                 <td>10R</td>
#                 <td class="positive-edge">5.8%</td>
#                 <td>26</td>
#                 <td>84%</td>
#                 <td>8.6</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMAs Agree + Direction Aligned</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>60</td>
#                 <td>33W – 27L</td>
#                 <td>55.0%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">5.0%</td>
#                 <td>21</td>
#                 <td>81%</td>
#                 <td>10.0</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">Both EMAs Aligned</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>60</td>
#                 <td>33W – 27L</td>
#                 <td>55.0%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">5.0%</td>
#                 <td>21</td>
#                 <td>81%</td>
#                 <td>10.0</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">Buy Only</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>86</td>
#                 <td>47W – 39L</td>
#                 <td>54.7%</td>
#                 <td>8R</td>
#                 <td class="positive-edge">4.7%</td>
#                 <td>27</td>
#                 <td>84%</td>
#                 <td>10.8</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMA(200) Aligned</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>86</td>
#                 <td>46W – 40L</td>
#                 <td>53.5%</td>
#                 <td>6R</td>
#                 <td class="positive-edge">3.5%</td>
#                 <td>26</td>
#                 <td>84%</td>
#                 <td>14.3</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">Buy Only</td>
#                 <td>+3.0</td>
#                 <td>1:1</td>
#                 <td>86</td>
#                 <td>45W – 41L</td>
#                 <td>52.3%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">2.3%</td>
#                 <td>27</td>
#                 <td>84%</td>
#                 <td>21.5</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">Buy Only</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>86</td>
#                 <td>45W – 41L</td>
#                 <td>52.3%</td>
#                 <td>4R</td>
#                 <td class="positive-edge">2.3%</td>
#                 <td>27</td>
#                 <td>84%</td>
#                 <td>21.5</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMA(200) Aligned</td>
#                 <td>+3.0</td>
#                 <td>1:1</td>
#                 <td>86</td>
#                 <td>44W – 42L</td>
#                 <td>51.2%</td>
#                 <td>2R</td>
#                 <td class="positive-edge">1.2%</td>
#                 <td>25</td>
#                 <td>81%</td>
#                 <td>43.0</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMA(50) Aligned</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>85</td>
#                 <td>43W – 42L</td>
#                 <td>50.6%</td>
#                 <td>1R</td>
#                 <td class="positive-edge">0.6%</td>
#                 <td>25</td>
#                 <td>78%</td>
#                 <td>85.0</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMAs Agree + Direction Aligned</td>
#                 <td>+3.0</td>
#                 <td>1:1</td>
#                 <td>60</td>
#                 <td>30W – 30L</td>
#                 <td>50.0%</td>
#                 <td>0R</td>
#                 <td class="negative-edge">0.0%</td>
#                 <td>20</td>
#                 <td>77%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">Both EMAs Aligned</td>
#                 <td>+3.0</td>
#                 <td>1:1</td>
#                 <td>60</td>
#                 <td>30W – 30L</td>
#                 <td>50.0%</td>
#                 <td>0R</td>
#                 <td class="negative-edge">0.0%</td>
#                 <td>20</td>
#                 <td>77%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMA(50) Against</td>
#                 <td>+3.0</td>
#                 <td>1:1</td>
#                 <td>93</td>
#                 <td>46W – 47L</td>
#                 <td>49.5%</td>
#                 <td>-1R</td>
#                 <td class="negative-edge">-0.5%</td>
#                 <td>26</td>
#                 <td>79%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">All Trades</td>
#                 <td>+5.0</td>
#                 <td>1:1</td>
#                 <td>178</td>
#                 <td>88W – 90L</td>
#                 <td>49.4%</td>
#                 <td>-2R</td>
#                 <td class="negative-edge">-0.6%</td>
#                 <td>31</td>
#                 <td>89%</td>
#                 <td>N/A</td>
#             </tr>
#             <tr>
#                 <td class="direction-strategy-col">EMA(50) Aligned</td>
#                 <td>+4.0</td>
#                 <td>1:1</td>
#                 <td>85</td>
#                 <td>42W – 43L</td>
#                 <td>49.4%</td>
#                 <td>-1R</td>
#                 <td c
