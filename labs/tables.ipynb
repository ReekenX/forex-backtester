# %% [markdown]
# # Forex Trading Strategy Analysis
#
# This notebook analyzes EUR/USD Forex trading data to identify profitable trading strategies based on various technical indicators and market conditions.

# %%
# Import required libraries
from IPython.display import display, HTML
import sys
import importlib

# Add parent directory to path to import utils
sys.path.insert(0, '..')

# Force reload of utils.tables module to prevent caching
# if 'utils.tables' in sys.modules:
#     del sys.modules['utils.tables']

# Enable automatic reloading of modules
# %load_ext autoreload
# %autoreload 2

# Import utility functions (will be freshly loaded)
from utils import load_and_clean_data
from utils import tables
from utils.tables import (
    display_30m_leg_analysis,
    display_pullback_analysis,
    display_sl_distribution_analysis,
    display_tp_distribution_analysis,
    display_sl_reduction_analysis,
    display_ema_30m_trend_analysis,
    display_triple_setup_strategy_analysis
)

# Force reload tables to ensure latest version
importlib.reload(tables)

# Load the data
df = load_and_clean_data()

# Display tables
display_30m_leg_analysis(df)
display_sl_distribution_analysis(df)
display_tp_distribution_analysis(df)
display_pullback_analysis(df)
display_sl_reduction_analysis(df)
display_ema_30m_trend_analysis(df)
display_triple_setup_strategy_analysis(df)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <h2>30M Leg Analysis</h2>
#     <style>
#         #sortable_table_e872ebe2 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_e872ebe2 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_e872ebe2 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_e872ebe2 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_e872ebe2 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_e872ebe2 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_e872ebe2 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_e872ebe2">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>30M Leg</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Below H</td>
#       <td>1:1</td>
#       <td>198</td>
#       <td>88</td>
#       <td>110</td>
#       <td>-22R</td>
#       <td>44.4%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>198</td>
#       <td>71</td>
#       <td>127</td>
#       <td>15R</td>
#       <td>35.9%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>198</td>
#       <td>55</td>
#       <td>143</td>
#       <td>22R</td>
#       <td>27.8%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Below L</td>
#       <td>1:1</td>
#       <td>273</td>
#       <td>106</td>
#       <td>167</td>
#       <td>-61R</td>
#       <td>38.8%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>273</td>
#       <td>82</td>
#       <td>191</td>
#       <td>-27R</td>
#       <td>30.0%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>273</td>
#       <td>69</td>
#       <td>204</td>
#       <td>3R</td>
#       <td>25.3%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Above L</td>
#       <td>1:1</td>
#       <td>293</td>
#       <td>108</td>
#       <td>185</td>
#       <td>-77R</td>
#       <td>36.9%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>293</td>
#       <td>80</td>
#       <td>213</td>
#       <td>-53R</td>
#       <td>27.3%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>293</td>
#       <td>64</td>
#       <td>229</td>
#       <td>-37R</td>
#       <td>21.8%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Above H</td>
#       <td>1:1</td>
#       <td>338</td>
#       <td>152</td>
#       <td>186</td>
#       <td>-34R</td>
#       <td>45.0%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>338</td>
#       <td>113</td>
#       <td>225</td>
#       <td>1R</td>
#       <td>33.4%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>338</td>
#       <td>84</td>
#       <td>254</td>
#       <td>-2R</td>
#       <td>24.9%</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Above H & Above L</td>
#       <td>1:1</td>
#       <td>631</td>
#       <td>260</td>
#       <td>371</td>
#       <td>-111R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td></td>
#       <td>1:2</td>
#       <td>631</td>
#       <td>193</td>
#       <td>438</td>
#       <td>-52R</td>
#       <td>30.6%</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td></td>
#       <td>1:3</td>
#       <td>631</td>
#       <td>148</td>
#       <td>483</td>
#       <td>-39R</td>
#       <td>23.5%</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Below H & Below L</td>
#       <td>1:1</td>
#       <td>471</td>
#       <td>194</td>
#       <td>277</td>
#       <td>-83R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td></td>
#       <td>1:2</td>
#       <td>471</td>
#       <td>153</td>
#       <td>318</td>
#       <td>-12R</td>
#       <td>32.5%</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td></td>
#       <td>1:3</td>
#       <td>471</td>
#       <td>124</td>
#       <td>347</td>
#       <td>25R</td>
#       <td>26.3%</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Continuation</td>
#       <td>1:1</td>
#       <td>611</td>
#       <td>258</td>
#       <td>353</td>
#       <td>-95R</td>
#       <td>42.2%</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td></td>
#       <td>1:2</td>
#       <td>611</td>
#       <td>195</td>
#       <td>416</td>
#       <td>-26R</td>
#       <td>31.9%</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td></td>
#       <td>1:3</td>
#       <td>611</td>
#       <td>153</td>
#       <td>458</td>
#       <td>1R</td>
#       <td>25.0%</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Reversal</td>
#       <td>1:1</td>
#       <td>491</td>
#       <td>196</td>
#       <td>295</td>
#       <td>-99R</td>
#       <td>39.9%</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td></td>
#       <td>1:2</td>
#       <td>491</td>
#       <td>151</td>
#       <td>340</td>
#       <td>-38R</td>
#       <td>30.8%</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td></td>
#       <td>1:3</td>
#       <td>491</td>
#       <td>119</td>
#       <td>372</td>
#       <td>-15R</td>
#       <td>24.2%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_e872ebe2');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6, 3, 4];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
# <h2>Stop Loss Distribution Analysis</h2>
#     <style>
#         #sortable_table_6354eee6 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_6354eee6 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_6354eee6 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_6354eee6 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_6354eee6 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_6354eee6 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_6354eee6 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_6354eee6">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SL Range</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>SL < 1</td>
#       <td>1:1</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>-5R</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>-5R</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>-5R</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1 ≤ SL < 5</td>
#       <td>1:1</td>
#       <td>524</td>
#       <td>170</td>
#       <td>354</td>
#       <td>-184R</td>
#       <td>32.4%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>524</td>
#       <td>146</td>
#       <td>378</td>
#       <td>-86R</td>
#       <td>27.9%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>524</td>
#       <td>118</td>
#       <td>406</td>
#       <td>-52R</td>
#       <td>22.5%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>5 ≤ SL < 10</td>
#       <td>1:1</td>
#       <td>451</td>
#       <td>223</td>
#       <td>228</td>
#       <td>-5R</td>
#       <td>49.4%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>451</td>
#       <td>164</td>
#       <td>287</td>
#       <td>41R</td>
#       <td>36.4%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>451</td>
#       <td>126</td>
#       <td>325</td>
#       <td>53R</td>
#       <td>27.9%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10 ≤ SL < 15</td>
#       <td>1:1</td>
#       <td>84</td>
#       <td>41</td>
#       <td>43</td>
#       <td>-2R</td>
#       <td>48.8%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>84</td>
#       <td>24</td>
#       <td>60</td>
#       <td>-12R</td>
#       <td>28.6%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>84</td>
#       <td>19</td>
#       <td>65</td>
#       <td>-8R</td>
#       <td>22.6%</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>SL ≥ 15</td>
#       <td>1:1</td>
#       <td>38</td>
#       <td>20</td>
#       <td>18</td>
#       <td>2R</td>
#       <td>52.6%</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td></td>
#       <td>1:2</td>
#       <td>38</td>
#       <td>12</td>
#       <td>26</td>
#       <td>-2R</td>
#       <td>31.6%</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td></td>
#       <td>1:3</td>
#       <td>38</td>
#       <td>9</td>
#       <td>29</td>
#       <td>-2R</td>
#       <td>23.7%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_6354eee6');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6, 3, 4];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
#                 });
#             }
#         }
#
#         // Apply initial green highlighting
#         applyWinRateHighlighting();
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[col
# <h2>Take Profit Distribution Analysis</h2>
#     <style>
#         #sortable_table_dbc1b869 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_dbc1b869 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_dbc1b869 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_dbc1b869 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_dbc1b869 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_dbc1b869 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_dbc1b869 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_dbc1b869">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TP Range</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>TP < 10</td>
#       <td>1:1</td>
#       <td>90</td>
#       <td>68</td>
#       <td>22</td>
#       <td>75.6%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>90</td>
#       <td>21</td>
#       <td>69</td>
#       <td>23.3%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>90</td>
#       <td>5</td>
#       <td>85</td>
#       <td>5.6%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10 ≤ TP < 20</td>
#       <td>1:1</td>
#       <td>156</td>
#       <td>140</td>
#       <td>16</td>
#       <td>89.7%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>156</td>
#       <td>95</td>
#       <td>61</td>
#       <td>60.9%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>156</td>
#       <td>54</td>
#       <td>102</td>
#       <td>34.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20 ≤ TP < 30</td>
#       <td>1:1</td>
#       <td>84</td>
#       <td>80</td>
#       <td>4</td>
#       <td>95.2%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>84</td>
#       <td>67</td>
#       <td>17</td>
#       <td>79.8%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>84</td>
#       <td>57</td>
#       <td>27</td>
#       <td>67.9%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>TP ≥ 30</td>
#       <td>1:1</td>
#       <td>170</td>
#       <td>166</td>
#       <td>4</td>
#       <td>97.6%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>170</td>
#       <td>163</td>
#       <td>7</td>
#       <td>95.9%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>170</td>
#       <td>156</td>
#       <td>14</td>
#       <td>91.8%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_dbc1b869');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [3, 4];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
#                 });
#             }
#         }
#
#         // Apply initial green highlighting
#         applyWinRateHighlighting();
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const colu
# <h2>Pullback Analysis</h2>
#     <style>
#         #sortable_table_bd9b5611 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_bd9b5611 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_bd9b5611 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_bd9b5611 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_bd9b5611 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_bd9b5611 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_bd9b5611 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_bd9b5611">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No Pullback</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>-194R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>-64R</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>-14R</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.5 pip Pullback</td>
#       <td>1:1</td>
#       <td>1090</td>
#       <td>449</td>
#       <td>641</td>
#       <td>-192R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1090</td>
#       <td>342</td>
#       <td>748</td>
#       <td>-64R</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1090</td>
#       <td>268</td>
#       <td>822</td>
#       <td>-18R</td>
#       <td>24.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>736</td>
#       <td>88</td>
#       <td>648</td>
#       <td>-384R</td>
#       <td>12.0%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_bd9b5611');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6, 3, 4];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
# <h2>SL Reduction Analysis</h2>
#     <style>
#         #sortable_table_dfaf5ab8 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_dfaf5ab8 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_dfaf5ab8 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_dfaf5ab8 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_dfaf5ab8 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_dfaf5ab8 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_dfaf5ab8 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_dfaf5ab8">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No adjustment</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>-194R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>-64R</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>-14R</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>271</td>
#       <td>831</td>
#       <td>-18R</td>
#       <td>24.6%</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1 pip reduction or max 15 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>402</td>
#       <td>700</td>
#       <td>-298R</td>
#       <td>36.5%</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>340</td>
#       <td>762</td>
#       <td>-82R</td>
#       <td>30.9%</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>269</td>
#       <td>833</td>
#       <td>-26R</td>
#       <td>24.4%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_dfaf5ab8');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6, 3, 4];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remo
# <h2>EMA and 30M Trend Alignment Analysis</h2>
#     <style>
#         #sortable_table_b5262402 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_b5262402 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_b5262402 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_b5262402 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_b5262402 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_b5262402 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_b5262402 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_b5262402">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Scenario</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Plain trading</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <
td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td></td>
#       <td>1:2</td>
#       <td>587</td>
#       <td>178</td>
#       <td>409</td>
#       <td>30.3%</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>587</td>
#       <td>150</td>
#       <td>437</td>
#       <td>25.6%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_b5262402');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [3, 4];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 win
# <h2>Triple Setup Strategies</h2>
#     <style>
#         #sortable_table_e031ee07 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_e031ee07 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_e031ee07 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_e031ee07 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_e031ee07 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_e031ee07 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_e031ee07 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_e031ee07">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#       <th>Trades Required</th>
#       <th>Drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td