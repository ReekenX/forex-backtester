# %% [markdown]
# # Single Setup Strategy Analysis
#
# This notebook analyzes individual trading strategy components without combining them.

# %%
# Import required modules
import sys
sys.path.insert(0, '..')

from IPython.display import display, HTML

# Enable automatic module reloading
# %load_ext autoreload
# %autoreload 2

from utils import load_and_clean_data
from utils.singles import display_single_setup_analysis

# %%
# Load data
df = load_and_clean_data()

# %%
# Display single setup strategy analysis
display_single_setup_analysis(df)

display(HTML("""
    <h2>Insights</h2>
    <p>EMA, BOS and 30M Trend giving really close results when traded alone.</p>
    <p>Previously my best strategy was based on "EMA", but this shows that "core" idea could be other two too.</p>
    <p>Tested out 30M Continuation and 30M Reversal, but they produced 2-3 times less trades. So they are not equally comparable to all three above.</p>
"""))
# Out:
# <h2>Single Setup Strategies</h2>
#     <style>
#         .singles-analysis-table {
#             border-collapse: collapse;
#             width: 100%;
#             font-family: monospace;
#             font-size: 12px;
#             color: #e0e0e0;
#             background-color: #1e1e1e;
#         }
#         .singles-analysis-table th {
#             background-color: #2d2d2d;
#             border: 1px solid #404040;
#             padding: 8px;
#             text-align: left;
#             cursor: pointer;
#             user-select: none;
#             color: #e0e0e0;
#         }
#         .singles-analysis-table th:hover {
#             background-color: #3d3d3d;
#         }
#         .singles-analysis-table td {
#             border: 1px solid #404040;
#             padding: 8px;
#             color: #e0e0e0;
#         }
#         .singles-analysis-table tr:nth-child(even) {
#             background-color: #252525;
#         }
#         .singles-analysis-table tr:nth-child(odd) {
#             background-color: #1e1e1e;
#         }
#         .singles-analysis-table .strategy-col {
#             width: 300px;
#             font-weight: bold;
#         }
#         .singles-analysis-table .positive-edge {
#             color: #4ade80;
#             font-weight: bold;
#         }
#         .singles-analysis-table .negative-edge {
#             color: #f87171;
#         }
#     </style>
#     <table class="singles-analysis-table">
#         <thead>
#             <tr>
#     <th>Strategy</th><th>RRR</th><th>Trades</th><th>Notation</th><th>Win Rate</th><th>Edge</th><th>Outcome</th><th>Days</th><th>Days %</th><th>Factor</th></tr></thead><tbody><tr><td class="strategy-col">30M Trend</td><td class="">1:3</td><td class="">622</td><td class="">164W – 458L</td><td class="">26.4%</td><td class="positive-edge">1.4%</td><td class="">34R</td><td class="">94</td><td class="positive-edge">61%</td><td class="">1.07</td></tr><tr><td class="strategy-col">EMA Aligned</td><td class="">1:3</td><td class="">703</td><td class="">179W – 524L</td><td class="">25.5%</td><td class="positive-edge">0.5%</td><td class="">13R</td><td class="">99</td><td class="positive-edge">64%</td><td class="">1.02</td></tr><tr><td class="strategy-col">BOS Only</td><td class="">1:3</td><td class="">757</td><td class="">190W – 567L</td><td class="">25.1%</td><td class="positive-edge">0.1%</td><td class="">3R</td><td class="">106</td><td class="positive-edge">68%</td><td class="">1.01</td></tr></tbody></table>
#     <h2>Insights</h2>
#     <p>EMA, BOS and 30M Trend giving really close results when traded alone.</p>
#     <p>Previously my best strategy was based on "EMA", but this shows that "core" idea could be other two too.</p>
#     <p>Tested out 30M Continuation and 30M Reversal, but they produced 2-3 times less trades. So they are not equally comparable to all three above.</p>
