# %% [markdown]
# # Forex Trading Strategy Analysis
#
# This notebook analyzes EUR/USD Forex trading data to identify profitable trading strategies based on various technical indicators and market conditions.

# %%
# Import required libraries
from IPython.display import display, HTML
import sys
import importlib

# Force reload of utils module to prevent caching
if 'utils' in sys.modules:
    del sys.modules['utils']

# Enable automatic reloading of modules
# %load_ext autoreload
# %autoreload 2

# Import utility functions (will be freshly loaded)
import utils
from utils import (
    load_and_clean_data,
    display_hour_analysis,
    display_weekday_analysis,
    display_pullback_analysis,
    display_sl_reduction_analysis,
    display_double_setup_strategy_analysis,
    display_single_setup_strategy_analysis,
    display_triple_setup_strategy_analysis
)

# Force reload utils to ensure latest version
importlib.reload(utils)

# Load the data
df = load_and_clean_data()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
display_hour_analysis(df)
display_weekday_analysis(df)
display_pullback_analysis(df)
display_sl_reduction_analysis(df)
display_single_setup_strategy_analysis(df)
display_double_setup_strategy_analysis(df)
display_triple_setup_strategy_analysis(df)
# Out:
# <h2>Hour Analysis</h2>
#     <style>
#         #sortable_table_4350b45c th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_4350b45c th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_4350b45c th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_4350b45c th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_4350b45c td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_4350b45c .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_4350b45c">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hour</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>10h</td>
#       <td>22</td>
#       <td>12</td>
#       <td>10</td>
#       <td>54.5%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11h</td>
#       <td>20</td>
#       <td>8</td>
#       <td>12</td>
#       <td>40.0%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12h</td>
#       <td>11</td>
#       <td>5</td>
#       <td>6</td>
#       <td>45.5%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13h</td>
#       <td>19</td>
#       <td>7</td>
#       <td>12</td>
#       <td>36.8%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14h</td>
#       <td>22</td>
#       <td>12</td>
#       <td>10</td>
#       <td>54.5%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>15h</td>
#       <td>22</td>
#       <td>11</td>
#       <td>11</td>
#       <td>50.0%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>16h</td>
#       <td>22</td>
#       <td>10</td>
#       <td>12</td>
#       <td>45.5%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>17h</td>
#       <td>20</td>
#       <td>12</td>
#       <td>8</td>
#       <td>60.0%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>18h</td>
#       <td>22</td>
#       <td>10</td>
#       <td>12</td>
#       <td>45.5%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_4350b45c');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const isAscending = this.classList.contains('sorted-asc');
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return isAscending ? 1 : -1;
#                     if (aValue > bValue) return isAscending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(isAscending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>Weekday Analysis</h2>
#     <style>
#         #sortable_table_fcbfceb6 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_fcbfceb6 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_fcbfceb6 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_fcbfceb6 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_fcbfceb6 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_fcbfceb6 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_fcbfceb6">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Weekday</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Monday</td>
#       <td>239</td>
#       <td>103</td>
#       <td>136</td>
#       <td>43.1%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Tuesday</td>
#       <td>214</td>
#       <td>106</td>
#       <td>108</td>
#       <td>49.5%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Wednesday</td>
#       <td>230</td>
#       <td>99</td>
#       <td>131</td>
#       <td>43.0%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Thursday</td>
#       <td>227</td>
#       <td>103</td>
#       <td>124</td>
#       <td>45.4%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Friday</td>
#       <td>192</td>
#       <td>87</td>
#       <td>105</td>
#       <td>45.3%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_fcbfceb6');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const isAscending = this.classList.contains('sorted-asc');
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return isAscending ? 1 : -1;
#                     if (aValue > bValue) return isAscending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(isAscending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>Pullback Analysis</h2>
#     <style>
#         #sortable_table_4f08e9de th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_4f08e9de th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_4f08e9de th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_4f08e9de th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_4f08e9de td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_4f08e9de .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_4f08e9de">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No Pullback</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Pullback >= 0.5 pips</td>
#       <td>1:1</td>
#       <td>1090</td>
#       <td>449</td>
#       <td>641</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1090</td>
#       <td>342</td>
#       <td>748</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1090</td>
#       <td>268</td>
#       <td>822</td>
#       <td>24.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Pullback >= 1.0 pip</td>
#       <td>1:1</td>
#       <td>974</td>
#       <td>342</td>
#       <td>632</td>
#       <td>35.1%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>974</td>
#       <td>255</td>
#       <td>719</td>
#       <td>26.2%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>974</td>
#       <td>198</td>
#       <td>776</td>
#       <td>20.3%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Pullback 50%</td>
#       <td>1:1</td>
#       <td>802</td>
#       <td>178</td>
#       <td>624</td>
#       <td>22.2%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>802</td>
#       <td>139</td>
#       <td>663</td>
#       <td>17.3%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>802</td>
#       <td>109</td>
#       <td>693</td>
#       <td>13.6%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_4f08e9de');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const isAscending = this.classList.contains('sorted-asc');
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return isAscending ? 1 : -1;
#                     if (aValue > bValue) return isAscending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(isAscending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>SL Reduction Analysis</h2>
#     <style>
#         #sortable_table_0b2f8899 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_0b2f8899 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_0b2f8899 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_0b2f8899 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_0b2f8899 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_0b2f8899 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_0b2f8899">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No adjustment</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1 pip reduction</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>402</td>
#       <td>700</td>
#       <td>36.5%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>338</td>
#       <td>764</td>
#       <td>30.7%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>269</td>
#       <td>833</td>
#       <td>24.4%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2 pips reduction</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>336</td>
#       <td>766</td>
#       <td>30.5%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>293</td>
#       <td>809</td>
#       <td>26.6%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>248</td>
#       <td>854</td>
#       <td>22.5%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1 pip reduction or max 4 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>325</td>
#       <td>777</td>
#       <td>29.5%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>304</td>
#       <td>798</td>
#       <td>27.6%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>267</td>
#       <td>835</td>
#       <td>24.2%</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1 pip reduction or max 5 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>358</td>
#       <td>744</td>
#       <td>32.5%</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>329</td>
#       <td>773</td>
#       <td>29.9%</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>270</td>
#       <td>832</td>
#       <td>24.5%</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1 pip reduction or max 6 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>375</td>
#       <td>727</td>
#       <td>34.0%</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>335</td>
#       <td>767</td>
#       <td>30.4%</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>270</td>
#       <td>832</td>
#       <td>24.5%</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1 pip reduction or max 7 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>386</td>
#       <td>716</td>
#       <td>35.0%</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>275</td>
#       <td>827</td>
#       <td>25.0%</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1 pip reduction or max 10 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>398</td>
#       <td>704</td>
#       <td>36.1%</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>348</td>
#       <td>754</td>
#       <td>31.6%</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>271</td>
#       <td>831</td>
#       <td>24.6%</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1 pip reduction or max 15 pip SL</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>402</td>
#       <td>700</td>
#       <td>36.5%</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>340</td>
#       <td>762</td>
#       <td>30.9%</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>269</td>
#       <td>833</td>
#       <td>24.4%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_0b2f8899');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const isAscending = this.classList.contains('sorted-asc');
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCel
# <h2>Single Setup Strategies</h2>
#     <style>
#         #sortable_table_8388b29a th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_8388b29a th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_8388b29a th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_8388b29a th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_8388b29a td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_8388b29a .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_8388b29a">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>News > 2hrs</td>
#       <td>1:3 RRR</td>
#       <td>44</td>
#       <td>13</td>
#       <td>31</td>
#       <td>29.5%</td>
#       <td>4.5%</td>
#       <td>8R</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>News > 2hrs</td>
#       <td>1:2 RRR</td>
#       <td>44</td>
#       <td>16</td>
#       <td>28</td>
#       <td>36.4%</td>
#       <td>3.1%</td>
#       <td>4R</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>SL ≥ 7 pips</td>
#       <td>1:1 RRR</td>
#       <td>298</td>
#       <td>157</td>
#       <td>141</td>
#       <td>52.7%</td>
#       <td>2.7%</td>
#       <td>16R</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>SL > 5 pips</td>
#       <td>1:2 RRR</td>
#       <td>557</td>
#       <td>200</td>
#       <td>357</td>
#       <td>35.9%</td>
#       <td>2.6%</td>
#       <td>43R</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>SL > 5 pips</td>
#       <td>1:3 RRR</td>
#       <td>557</td>
#       <td>152</td>
#       <td>405</td>
#       <td>27.3%</td>
#       <td>2.3%</td>
#       <td>51R</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>SL > 5 pips</td>
#       <td>1:1 RRR</td>
#       <td>557</td>
#       <td>289</td>
#       <td>268</td>
#       <td>51.9%</td>
#       <td>1.9%</td>
#       <td>21R</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>EMA Aligned</td>
#       <td>1:3 RRR</td>
#       <td>702</td>
#       <td>186</td>
#       <td>516</td>
#       <td>26.5%</td>
#       <td>1.5%</td>
#       <td>42R</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>SL > 15 pips</td>
#       <td>1:1 RRR</td>
#       <td>37</td>
#       <td>19</td>
#       <td>18</td>
#       <td>51.4%</td>
#       <td>1.4%</td>
#       <td>1R</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BOS Only</td>
#       <td>1:3 RRR</td>
#       <td>757</td>
#       <td>200</td>
#       <td>557</td>
#       <td>26.4%</td>
#       <td>1.4%</td>
#       <td>43R</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>SL > 10 pips</td>
#       <td>1:1 RRR</td>
#       <td>119</td>
#       <td>61</td>
#       <td>58</td>
#       <td>51.3%</td>
#       <td>1.3%</td>
#       <td>3R</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>SL 1-3 pips</td>
#       <td>1:3 RRR</td>
#       <td>175</td>
#       <td>46</td>
#       <td>129</td>
#       <td>26.3%</td>
#       <td>1.3%</td>
#       <td>9R</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Sell Trades Only</td>
#       <td>1:3 RRR</td>
#       <td>537</td>
#       <td>140</td>
#       <td>397</td>
#       <td>26.1%</td>
#       <td>1.1%</td>
#       <td>23R</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>SL < 10 pips</td>
#       <td>1:3 RRR</td>
#       <td>979</td>
#       <td>254</td>
#       <td>725</td>
#       <td>25.9%</td>
#       <td>0.9%</td>
#       <td>37R</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>No News</td>
#       <td>1:3 RRR</td>
#       <td>1031</td>
#       <td>267</td>
#       <td>764</td>
#       <td>25.9%</td>
#       <td>0.9%</td>
#       <td>37R</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>SL < 15 pips</td>
#       <td>1:3 RRR</td>
#       <td>1064</td>
#       <td>274</td>
#       <td>790</td>
#       <td>25.8%</td>
#       <td>0.8%</td>
#       <td>32R</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>SL ≥ 7 pips</td>
#       <td>1:3 RRR</td>
#       <td>298</td>
#       <td>77</td>
#       <td>221</td>
#       <td>25.8%</td>
#       <td>0.8%</td>
#       <td>10R</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>SL > 3 pips</td>
#       <td>1:3 RRR</td>
#       <td>922</td>
#       <td>237</td>
#       <td>685</td>
#       <td>25.7%</td>
#       <td>0.7%</td>
#       <td>26R</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Plain Strategy</td>
#       <td>1:3 RRR</td>
#       <td>1102</td>
#       <td>283</td>
#       <td>819</td>
#       <td>25.7%</td>
#       <td>0.7%</td>
#       <td>30R</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Buy Trades Only</td>
#       <td>1:2 RRR</td>
#       <td>565</td>
#       <td>192</td>
#       <td>373</td>
#       <td>34.0%</td>
#       <td>0.7%</td>
#       <td>11R</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>30M Trend</td>
#       <td>1:3 RRR</td>
#       <td>110</td>
#       <td>28</td>
#       <td>82</td>
#       <td>25.5%</td>
#       <td>0.5%</td>
#       <td>2R</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>SL 9-15 pips</td>
#       <td>1:1 RRR</td>
#       <td>113</td>
#       <td>57</td>
#       <td>56</td>
#       <td>50.4%</td>
#       <td>0.4%</td>
#       <td>1R</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Pullback ≥ 0.5 pips</td>
#       <td>1:3 RRR</td>
#       <td>1090</td>
#       <td>277</td>
#       <td>813</td>
#       <td>25.4%</td>
#       <td>0.4%</td>
#       <td>18R</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>SL 4-8 pips</td>
#       <td>1:3 RRR</td>
#       <td>559</td>
#       <td>142</td>
#       <td>417</td>
#       <td>25.4%</td>
#       <td>0.4%</td>
#       <td>9R</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>SL 4-8 pips</td>
#       <td>1:2 RRR</td>
#       <td>559</td>
#       <td>188</td>
#       <td>371</td>
#       <td>33.6%</td>
#       <td>0.3%</td>
#       <td>5R</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Buy Trades Only</td>
#       <td>1:3 RRR</td>
#       <td>565</td>
#       <td>143</td>
#       <td>422</td>
#       <td>25.3%</td>
#       <td>0.3%</td>
#       <td>7R</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>EMA Aligned</td>
#       <td>1:2 RRR</td>
#       <td>702</td>
#       <td>235</td>
#       <td>467</td>
#       <td>33.5%</td>
#       <td>0.2%</td>
#       <td>3R</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>BOS Only</td>
#       <td>1:2 RRR</td>
#       <td>757</td>
#       <td>253</td>
#       <td>504</td>
#       <td>33.4%</td>
#       <td>0.1%</td>
#       <td>2R</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_8388b29a');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [7, 8];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = 'Edge';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
# <h2>Double Setup Strategies</h2>
#     <style>
#         #sortable_table_24ca8b28 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_24ca8b28 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_24ca8b28 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_24ca8b28 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_24ca8b28 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_24ca8b28 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_24ca8b28">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>BOS + News > 2hrs</td>
#       <td>1:3 RRR</td>
#       <td>27</td>
#       <td>9</td>
#       <td>18</td>
#       <td>33.3%</td>
#       <td>8.3%</td>
#       <td>9R</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>30M Trend + SL > 5</td>
#       <td>1:1 RRR</td>
#       <td>42</td>
#       <td>24</td>
#       <td>18</td>
#       <td>57.1%</td>
#       <td>7.1%</td>
#       <td>6R</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>30M Trend + News > 2hrs</td>
#       <td>1:3 RRR</td>
#       <td>22</td>
#       <td>7</td>
#       <td>15</td>
#       <td>31.8%</td>
#       <td>6.8%</td>
#       <td>6R</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BOS + SL ≤ 2</td>
#       <td>1:3 RRR</td>
#       <td>50</td>
#       <td>15</td>
#       <td>35</td>
#       <td>30.0%</td>
#       <td>5.0%</td>
#       <td>10R</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>30M Trend + BOS</td>
#       <td>1:3 RRR</td>
#       <td>77</td>
#       <td>23</td>
#       <td>54</td>
#       <td>29.9%</td>
#       <td>4.9%</td>
#       <td>15R</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>EMA + SL ≤ 2</td>
#       <td>1:3 RRR</td>
#       <td>44</td>
#       <td>13</td>
#       <td>31</td>
#       <td>29.5%</td>
#       <td>4.5%</td>
#       <td>8R</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BOS + News > 2hrs</td>
#       <td>1:2 RRR</td>
#       <td>27</td>
#       <td>10</td>
#       <td>17</td>
#       <td>37.0%</td>
#       <td>3.7%</td>
#       <td>3R</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>30M Trend + BOS</td>
#       <td>1:2 RRR</td>
#       <td>77</td>
#       <td>28</td>
#       <td>49</td>
#       <td>36.4%</td>
#       <td>3.1%</td>
#       <td>7R</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>30M Trend + News > 2hrs</td>
#       <td>1:2 RRR</td>
#       <td>22</td>
#       <td>8</td>
#       <td>14</td>
#       <td>36.4%</td>
#       <td>3.1%</td>
#       <td>2R</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>EMA + SL < 10</td>
#       <td>1:3 RRR</td>
#       <td>624</td>
#       <td>172</td>
#       <td>452</td>
#       <td>27.6%</td>
#       <td>2.6%</td>
#       <td>64R</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>EMA + BOS</td>
#       <td>1:3 RRR</td>
#       <td>586</td>
#       <td>160</td>
#       <td>426</td>
#       <td>27.3%</td>
#       <td>2.3%</td>
#       <td>54R</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>CH + News > 2hrs</td>
#       <td>1:2 RRR</td>
#       <td>17</td>
#       <td>6</td>
#       <td>11</td>
#       <td>35.3%</td>
#       <td>2.0%</td>
#       <td>1R</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>30M Trend + BOS</td>
#       <td>1:1 RRR</td>
#       <td>77</td>
#       <td>40</td>
#       <td>37</td>
#       <td>51.9%</td>
#       <td>1.9%</td>
#       <td>3R</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>EMA + No News</td>
#       <td>1:3 RRR</td>
#       <td>659</td>
#       <td>177</td>
#       <td>482</td>
#       <td>26.9%</td>
#       <td>1.9%</td>
#       <td>49R</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>BOS + No News</td>
#       <td>1:3 RRR</td>
#       <td>716</td>
#       <td>188</td>
#       <td>528</td>
#       <td>26.3%</td>
#       <td>1.3%</td>
#       <td>36R</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>EMA + SL < 10</td>
#       <td>1:2 RRR</td>
#       <td>624</td>
#       <td>216</td>
#       <td>408</td>
#       <td>34.6%</td>
#       <td>1.3%</td>
#       <td>24R</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>30M Trend + SL < 15</td>
#       <td>1:3 RRR</td>
#       <td>108</td>
#       <td>28</td>
#       <td>80</td>
#       <td>25.9%</td>
#       <td>0.9%</td>
#       <td>4R</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>30M Trend + SL < 10</td>
#       <td>1:3 RRR</td>
#       <td>101</td>
#       <td>26</td>
#       <td>75</td>
#       <td>25.7%</td>
#       <td>0.7%</td>
#       <td>3R</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Plain Strategy</td>
#       <td>1:3 RRR</td>
#       <td>1102</td>
#       <td>283</td>
#       <td>819</td>
#       <td>25.7%</td>
#       <td>0.7%</td>
#       <td>30R</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>BOS + SL 3-6</td>
#       <td>1:3 RRR</td>
#       <td>359</td>
#       <td>92</td>
#       <td>267</td>
#       <td>25.6%</td>
#       <td>0.6%</td>
#       <td>9R</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>EMA + No News</td>
#       <td>1:2 RRR</td>
#       <td>659</td>
#       <td>223</td>
#       <td>436</td>
#       <td>33.8%</td>
#       <td>0.5%</td>
#       <td>10R</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>EMA + BOS</td>
#       <td>1:2 RRR</td>
#       <td>586</td>
#       <td>198</td>
#       <td>388</td>
#       <td>33.8%</td>
#       <td>0.5%</td>
#       <td>8R</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>EMA + SL 3-6</td>
#       <td>1:2 RRR</td>
#       <td>328</td>
#       <td>111</td>
#       <td>217</td>
#       <td>33.8%</td>
#       <td>0.5%</td>
#       <td>5R</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>30M Trend + SL < 10</td>
#       <td>1:2 RRR</td>
#       <td>101</td>
#       <td>34</td>
#       <td>67</td>
#       <td>33.7%</td>
#       <td>0.4%</td>
#       <td>1R</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>30M Trend + No News</td>
#       <td>1:3 RRR</td>
#       <td>75</td>
#       <td>19</td>
#       <td>56</td>
#       <td>25.3%</td>
#       <td>0.3%</td>
#       <td>1R</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>EMA + SL 3-6</td>
#       <td>1:3 RRR</td>
#       <td>328</td>
#       <td>83</td>
#       <td>245</td>
#       <td>25.3%</td>
#       <td>0.3%</td>
#       <td>4R</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>BOS + No News</td>
#       <td>1:2 RRR</td>
#       <td>716</td>
#       <td>239</td>
#       <td>477</td>
#       <td>33.4%</td>
#       <td>0.1%</td>
#       <td>1R</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>CH + No News</td>
#       <td>1:3 RRR</td>
#       <td>315</td>
#       <td>79</td>
#       <td>236</td>
#       <td>25.1%</td>
#       <td>0.1%</td>
#       <td>1R</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_24ca8b28');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [7, 8];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = 'Edge';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
# <h2>Triple Setup Strategies</h2>
#     <style>
#         #sortable_table_6ff52196 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_6ff52196 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_6ff52196 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_6ff52196 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_6ff52196 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_6ff52196 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_6ff52196">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>30M Trend + 5 < SL < 15</td>
#       <td>1:1 RRR</td>
#       <td>40</td>
#       <td>23</td>
#       <td>17</td>
#       <td>57.5%</td>
#       <td>7.5%</td>
#       <td>6R</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>30M Trend + BOS + SL < 10</td>
#       <td>1:3 RRR</td>
#       <td>71</td>
#       <td>22</td>
#       <td>49</td>
#       <td>31.0%</td>
#       <td>6.0%</td>
#       <td>17R</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>30M Trend + BOS + SL < 10</td>
#       <td>1:2 RRR</td>
#       <td>71</td>
#       <td>27</td>
#       <td>44</td>
#       <td>38.0%</td>
#       <td>4.7%</td>
#       <td>10R</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>30M Trend + EMA + BOS + SL < 10</td>
#       <td>1:3 RRR</td>
#       <td>62</td>
#       <td>18</td>
#       <td>44</td>
#       <td>29.0%</td>
#       <td>4.0%</td>
#       <td>10R</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>30M Trend + EMA + BOS</td>
#       <td>1:3 RRR</td>
#       <td>68</td>
#       <td>19</td>
#       <td>49</td>
#       <td>27.9%</td>
#       <td>2.9%</td>
#       <td>8R</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>30M Trend + BOS + SL < 10</td>
#       <td>1:1 RRR</td>
#       <td>71</td>
#       <td>37</td>
#       <td>34</td>
#       <td>52.1%</td>
#       <td>2.1%</td>
#       <td>3R</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>30M Trend + 5 < SL < 15</td>
#       <td>1:2 RRR</td>
#       <td>40</td>
#       <td>14</td>
#       <td>26</td>
#       <td>35.0%</td>
#       <td>1.7%</td>
#       <td>2R</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Plain Strategy</td>
#       <td>1:3 RRR</td>
#       <td>1102</td>
#       <td>283</td>
#       <td>819</td>
#       <td>25.7%</td>
#       <td>0.7%</td>
#       <td>30R</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>30M Trend + EMA + BOS + SL < 10</td>
#       <td>1:2 RRR</td>
#       <td>62</td>
#       <td>21</td>
#       <td>41</td>
#       <td>33.9%</td>
#       <td>0.6%</td>
#       <td>1R</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_6ff52196');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [7, 8];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = 'Edge';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const isAscending = this.classList.contains('sorted-asc');
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return isAscending ? 1 : -1;
#                     if (aValue > bValue) return isAscending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(isAscending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
