# %% [markdown]
# # Forex Trading Strategy Analysis
#
# This notebook analyzes EUR/USD Forex trading data to identify profitable trading strategies based on various technical indicators and market conditions.

# %%
# Import required libraries
from IPython.display import display, HTML
import sys
import importlib

# Force reload of utils module to prevent caching
if 'utils' in sys.modules:
    del sys.modules['utils']

# Enable automatic reloading of modules
# %load_ext autoreload
# %autoreload 2

# Import utility functions (will be freshly loaded)
import utils
from utils import (
    load_and_clean_data,
    display_hour_analysis,
    display_weekday_analysis,
    display_pullback_analysis,
    display_sl_distribution_analysis,
    display_sl_reduction_analysis,
    display_double_setup_strategy_analysis,
    display_single_setup_strategy_analysis,
    display_triple_setup_strategy_analysis,
    display_strategy_cumulative_chart
)

# Force reload utils to ensure latest version
importlib.reload(utils)

# Load the data
df = load_and_clean_data()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
display_hour_analysis(df)
display_weekday_analysis(df)
display_sl_distribution_analysis(df)
display_pullback_analysis(df)
display_sl_reduction_analysis(df)
display_single_setup_strategy_analysis(df)
display_double_setup_strategy_analysis(df)
display_triple_setup_strategy_analysis(df)
# Out:
# <h2>Hour Analysis</h2>
#     <style>
#         #sortable_table_d3b16d75 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_d3b16d75 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_d3b16d75 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_d3b16d75 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_d3b16d75 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_d3b16d75 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_d3b16d75">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hour</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>10h</td>
#       <td>156</td>
#       <td>82</td>
#       <td>74</td>
#       <td>52.6%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11h</td>
#       <td>136</td>
#       <td>56</td>
#       <td>80</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12h</td>
#       <td>118</td>
#       <td>44</td>
#       <td>74</td>
#       <td>37.3%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13h</td>
#       <td>120</td>
#       <td>51</td>
#       <td>69</td>
#       <td>42.5%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14h</td>
#       <td>108</td>
#       <td>51</td>
#       <td>57</td>
#       <td>47.2%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>15h</td>
#       <td>117</td>
#       <td>51</td>
#       <td>66</td>
#       <td>43.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>16h</td>
#       <td>120</td>
#       <td>59</td>
#       <td>61</td>
#       <td>49.2%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>17h</td>
#       <td>123</td>
#       <td>63</td>
#       <td>60</td>
#       <td>51.2%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>18h</td>
#       <td>104</td>
#       <td>42</td>
#       <td>62</td>
#       <td>40.4%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_d3b16d75');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const columnName = this.textContent.trim();
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Determine sort direction based on column type
#                 let sortDescending = true; // Default to descending
#                 if (columnName === 'Trades Required') {
#                     sortDescending = false; // Trades Required should be ascending (lowest to highest)
#                 }
#                 // Edge and Outcome columns use descending (highest to lowest) - default behavior
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return sortDescending ? 1 : -1;
#                     if (aValue > bValue) return sortDescending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(sortDescending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>Weekday Analysis</h2>
#     <style>
#         #sortable_table_3d1acae1 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_3d1acae1 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_3d1acae1 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_3d1acae1 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_3d1acae1 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_3d1acae1 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_3d1acae1">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Weekday</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Monday</td>
#       <td>239</td>
#       <td>103</td>
#       <td>136</td>
#       <td>43.1%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Tuesday</td>
#       <td>214</td>
#       <td>107</td>
#       <td>107</td>
#       <td>50.0%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Wednesday</td>
#       <td>229</td>
#       <td>99</td>
#       <td>130</td>
#       <td>43.2%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Thursday</td>
#       <td>227</td>
#       <td>103</td>
#       <td>124</td>
#       <td>45.4%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Friday</td>
#       <td>193</td>
#       <td>87</td>
#       <td>106</td>
#       <td>45.1%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_3d1acae1');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const columnName = this.textContent.trim();
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Determine sort direction based on column type
#                 let sortDescending = true; // Default to descending
#                 if (columnName === 'Trades Required') {
#                     sortDescending = false; // Trades Required should be ascending (lowest to highest)
#                 }
#                 // Edge and Outcome columns use descending (highest to lowest) - default behavior
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return sortDescending ? 1 : -1;
#                     if (aValue > bValue) return sortDescending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(sortDescending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>Stop Loss Distribution Analysis</h2>
#     <style>
#         #sortable_table_976c7f90 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_976c7f90 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_976c7f90 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_976c7f90 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_976c7f90 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_976c7f90 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_976c7f90">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SL Range</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>SL < 1</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1 ≤ SL < 2</td>
#       <td>48</td>
#       <td>11</td>
#       <td>37</td>
#       <td>22.9%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2 ≤ SL < 3</td>
#       <td>109</td>
#       <td>38</td>
#       <td>71</td>
#       <td>34.9%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3 ≤ SL < 4</td>
#       <td>186</td>
#       <td>68</td>
#       <td>118</td>
#       <td>36.6%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4 ≤ SL < 5</td>
#       <td>181</td>
#       <td>71</td>
#       <td>110</td>
#       <td>39.2%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>5 ≤ SL < 10</td>
#       <td>451</td>
#       <td>246</td>
#       <td>205</td>
#       <td>54.5%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>10 ≤ SL < 15</td>
#       <td>84</td>
#       <td>43</td>
#       <td>41</td>
#       <td>51.2%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>SL ≥ 15</td>
#       <td>38</td>
#       <td>22</td>
#       <td>16</td>
#       <td>57.9%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_976c7f90');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const columnName = this.textContent.trim();
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Determine sort direction based on column type
#                 let sortDescending = true; // Default to descending
#                 if (columnName === 'Trades Required') {
#                     sortDescending = false; // Trades Required should be ascending (lowest to highest)
#                 }
#                 // Edge and Outcome columns use descending (highest to lowest) - default behavior
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return sortDescending ? 1 : -1;
#                     if (aValue > bValue) return sortDescending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(sortDescending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>Pullback Analysis</h2>
#     <style>
#         #sortable_table_6a40e130 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_6a40e130 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_6a40e130 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_6a40e130 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_6a40e130 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_6a40e130 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_6a40e130">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No Pullback</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Pullback >= 0.5 pips</td>
#       <td>1:1</td>
#       <td>1090</td>
#       <td>449</td>
#       <td>641</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1090</td>
#       <td>342</td>
#       <td>748</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1090</td>
#       <td>268</td>
#       <td>822</td>
#       <td>24.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Pullback >= 1.0 pip</td>
#       <td>1:1</td>
#       <td>974</td>
#       <td>342</td>
#       <td>632</td>
#       <td>35.1%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>974</td>
#       <td>255</td>
#       <td>719</td>
#       <td>26.2%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>974</td>
#       <td>198</td>
#       <td>776</td>
#       <td>20.3%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Pullback 50%</td>
#       <td>1:1</td>
#       <td>802</td>
#       <td>178</td>
#       <td>624</td>
#       <td>22.2%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>802</td>
#       <td>139</td>
#       <td>663</td>
#       <td>17.3%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>802</td>
#       <td>109</td>
#       <td>693</td>
#       <td>13.6%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_6a40e130');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const columnName = this.textContent.trim();
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Determine sort direction based on column type
#                 let sortDescending = true; // Default to descending
#                 if (columnName === 'Trades Required') {
#                     sortDescending = false; // Trades Required should be ascending (lowest to highest)
#                 }
#                 // Edge and Outcome columns use descending (highest to lowest) - default behavior
#
#                 // Sort rows
#                 rows.sort((a, b) => {
#                     const aCell = a.children[colIndex];
#                     const bCell = b.children[colIndex];
#
#                     let aValue = aCell.textContent.trim();
#                     let bValue = bCell.textContent.trim();
#
#                     // Handle percentage values
#                     if (aValue.includes('%')) {
#                         aValue = parseFloat(aValue.replace('%', '')) || 0;
#                         bValue = parseFloat(bValue.replace('%', '')) || 0;
#                     }
#                     // Handle currency values
#                     else if (aValue.includes('$')) {
#                         aValue = parseFloat(aValue.replace(/[\$,]/g, '')) || 0;
#                         bValue = parseFloat(bValue.replace(/[\$,]/g, '')) || 0;
#                     }
#                     // Handle regular numbers
#                     else {
#                         const aNum = parseFloat(aValue);
#                         const bNum = parseFloat(bValue);
#                         if (!isNaN(aNum) && !isNaN(bNum)) {
#                             aValue = aNum;
#                             bValue = bNum;
#                         }
#                     }
#
#                     if (aValue < bValue) return sortDescending ? 1 : -1;
#                     if (aValue > bValue) return sortDescending ? -1 : 1;
#                     return 0;
#                 });
#
#                 // Update the class for visual indicator
#                 this.classList.add(sortDescending ? 'sorted-desc' : 'sorted-asc');
#
#                 // Re-append sorted rows
#                 rows.forEach(row => tbody.appendChild(row));
#
#                 // Highlight the clicked column
#                 applyHighlighting(colIndex);
#             });
#         });
#     })();
#     </script>
# <h2>SL Reduction Analysis</h2>
#     <style>
#         #sortable_table_5217c44e th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_5217c44e th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_5217c44e th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_5217c44e th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_5217c44e td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_5217c44e .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_5217c44e">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No adjustment</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1 pip reduction</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>402</td>
#       <td>700</td>
#       <td>36.5%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <
td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>269</td>
#       <td>833</td>
#       <td>24.4%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_5217c44e');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const columnName = this.textContent.trim();
#
#                 // Remove sort
# <h2>Single Setup Strategies</h2>
#     <style>
#         #sortable_table_0e816bc3 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_0e816bc3 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_0e816bc3 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_0e816bc3 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_0e816bc3 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_0e816bc3 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_0e816bc3">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#       <th>Trades Required</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>SL ≥ 7 pips</td>
#       <td>1:1 RRR</td>
#       <td>298</td>
#       <td>157</td>
#       <td>141</td>
#       <td>52.7%</td>
#       <td>2.7%</td>
#       <td>16R</td>
#       <td>18.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>EMA Aligned</td>
#       <td>1:2 RRR</td>
#       <td>703</td>
#       <td>235</td>
#       <td>468</td>
#       <td>33.4%</td>
#       <td>0.1%</td>
#       <td>2R</td>
#       <td>351.5</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_0e816bc3');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [7, 8, 9];
#
#         // Store the currently highlighte
# <h2>Double Setup Strategies</h2>
#     <style>
#         #sortable_table_5e73afb0 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_5e73afb0 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_5e73afb0 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_5e73afb0 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_5e73afb0 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_5e73afb0 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_5e73afb0">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#       <th>Trades Required</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>BOS + SL ≤ 2</td>
#       <td>1:3 RRR</td>
#       <td>50</td>
#       <td>15</td>
#       <td>35</td>
#       <td>30.0%</td>
#       <td>5.0%</td>
#       <td>10R</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CH + News > 2hrs</td>
#       <td>1:3 RRR</td>
#       <td>100</td>
#       <td>30</td>
#       <td>70</td>
#       <td>30.0%</td>
#       <td>5.0%</td>
#       <td>20R</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CH + News > 2hrs</td>
#       <td>1:2 RRR</td>
#       <td>100</td>
#       <td>38</td>
#       <td>62</td>
#       <td>38.0%</td>
#       <td>4.7%</td>
#       <td>14R</td>
#       <td>7.1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>EMA + SL ≤ 2</td>
#       <td>1:3 RRR</td>
#       <td>44</td>
#       <td>13</td>
#       <td>31</td>
#       <td>29.5%</td>
#       <td>4.5%</td>
#       <td>8R</td>
#       <td>5.5</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>30M Trend + SL > 5</td>
#       <td>1:2 RRR</td>
#       <td>315</td>
#       <td>118</td>
#       <td>197</td>
#       <td>37.5%</td>
#       <td>4.2%</td>
#       <td>39R</td>
#       <td>8.1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>30M Trend + BOS</td>
#       <td>1:3 RRR</td>
#       <td>466</td>
#       <td>135</td>
#       <td>331</td>
#       <td>29.0%</td>
#       <td>4.0%</td>
#       <td>74R</td>
#       <td>6.3</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>30M Trend + SL > 5</td>
#       <td>1:1 RRR</td>
#       <td>315</td>
#       <td>169</td>
#       <td>146</td>
#       <td>53.7%</td>
#       <td>3.7%</td>
#       <td>23R</td>
#       <td>13.7</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>30M Trend + News > 2hrs</td>
#       <td>1:3 RRR</td>
#       <td>185</td>
#       <td>53</td>
#       <td>132</td>
#       <td>28.6%</td>
#       <td>3.6%</td>
#       <td>27R</td>
#       <td>6.9</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>BOS + No News</td>
#       <td>1:3 RRR</td>
#       <td>444</td>
#       <td>118</td>
#       <td>326</td>
#       <td>26.6%</td>
#       <td>1.6%</td>
#       <td>28R</td>
#       <td>15.9</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>30M Trend + SL < 15</td>
#       <td>1:2 RRR</td>
#       <td>599</td>
#       <td>208</td>
#       <td>391</td>
#       <td>34.7%</td>
#       <td>1.4%</td>
#       <td>25R</td>
#       <td>24.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>BOS + No News</td>
#       <td>1:2 RRR</td>
#       <td>444</td>
#       <td>153</td>
#       <td>291</td>
#       <td>34.5%</td>
#       <td>1.2%</td>
#       <td>15R</td>
#       <td>29.6</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>EMA + SL < 10</td>
#       <td>1:2 RRR</td>
#       <td>626</td>
#       <td>216</td>
#       <td>410</td>
#       <td>34.5%</td>
#       <td>1.2%</td>
#       <td>22R</td>
#       <td>28.5</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>30M Trend + No News</td>
#       <td>1:2 RRR</td>
#       <td>369</td>
#       <td>127</td>
#       <td>242</td>
#       <td>34.4%</td>
#       <td>1.1%</td>
#       <td>12R</td>
#       <td>30.8</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>30M Trend + EMA</td>
#       <td>1:2 RRR</td>
#       <td>481</td>
#       <td>165</td>
#       <td>316</td>
#       <td>34.3%</td>
#       <td>1.0%</td>
#       <td>14R</td>
#       <td>34.4</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>BOS + SL 3-6</td>
#       <td>1:3 RRR</td>
#       <td>359</td>
#       <td>93</td>
#       <td>266</td>
#       <td>25.9%</td>
#       <td>0.9%</td>
#       <td>13R</td>
#       <td>27.6</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Plain Strategy</td>
#       <td>1:3 RRR</td>
#       <td>1102</td>
#       <td>284</td>
#       <td>818</td>
#       <td>25.8%</td>
#       <td>0.8%</td>
#       <td>34R</td>
#       <td>32.4</td>
#     </tr>
# <h2>Triple Setup Strategies</h2>
#     <style>
#         #sortable_table_5e3fe8e0 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_5e3fe8e0 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_5e3fe8e0 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_5e3fe8e0 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_5e3fe8e0 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_5e3fe8e0 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_5e3fe8e0">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#       <th>Trades Required</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>30M Trend + EMA + BOS + SL < 10</td>
#       <td>1:3 RRR</td>
#       <td>361</td>
#       <td>110</td>
#       <td>251</td>
#       <td>30.5%</td>
#       <td>5.5%</td>
#       <td>79R</td>
#       <td>4.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>30M Trend + EMA + SL < 10</td>
#       <td>1:2 RRR</td>
#       <td>423</td>
#       <td>151</td>
#       <td>272</td>
#       <td>35.7%</td>
#       <td>2.4%</td>
#       <td>30R</td>
#       <td>14.1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Plain Strategy</td>
#       <td>1:3 RRR</td>
#       <td>1102</td>
#       <td>284</td>
#       <td>818</td>
#       <td>25.8%</td>
#       <td>0.8%</td>
#       <td>34R</td>
#       <td>32.4</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_5e3fe8e0');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [7, 8, 9];
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = 'Edge';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const columnName = this.textContent.trim();
#
#                 // Remove sorted classes from all headers
#                 headers.forEach(h => {
#                     h.classList.remove('sorted-asc', 'sorted-desc');
#                 });
#
#                 // Determine sort direction based on column type
#                 let sortDescending = true; // Default to descending
#                 if (columnName === 'Trades Required') {
#                     sortDescending = false; // Trades Required should be ascending (lowes

# %%
display_strategy_cumulative_chart(df, strategy_name="30M Trend + BOS + SL < 10", rrr=1)
# Out:
#     <p style="font-size: 14px;">
#         <strong>Summary:</strong> 414 trades |
#         194 wins | 220 losses |
#         Win rate: 46.9% |
#         Final outcome: <span style="color: red; font-weight: bold;">-26.0R</span>
#     </p>
