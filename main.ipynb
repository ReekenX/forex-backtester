# %% [markdown]
# # Forex Trading Strategy Analysis
#
# This notebook analyzes EUR/USD Forex trading data to identify profitable trading strategies based on various technical indicators and market conditions.

# %%
# Import required libraries
from IPython.display import display, HTML
import sys
import importlib

# Force reload of utils module to prevent caching
if 'utils' in sys.modules:
    del sys.modules['utils']

# Enable automatic reloading of modules
# %load_ext autoreload
# %autoreload 2

# Import utility functions (will be freshly loaded)
import utils
from utils import (
    load_and_clean_data,
    display_hour_analysis,
    display_weekday_analysis,
    display_30m_leg_analysis,
    display_pullback_analysis,
    display_sl_distribution_analysis,
    display_tp_distribution_analysis,
    display_sl_reduction_analysis,
    display_ema_30m_trend_analysis,
    display_double_setup_strategy_analysis,
    display_single_setup_strategy_analysis,
    display_triple_setup_strategy_analysis
)

# Force reload utils to ensure latest version
importlib.reload(utils)

# Load the data
df = load_and_clean_data()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
display_hour_analysis(df)
display_weekday_analysis(df)
display_30m_leg_analysis(df)
display_sl_distribution_analysis(df)
display_tp_distribution_analysis(df)
display_pullback_analysis(df)
display_sl_reduction_analysis(df)
display_ema_30m_trend_analysis(df)
display_single_setup_strategy_analysis(df)
display_double_setup_strategy_analysis(df)
display_triple_setup_strategy_analysis(df)
# Out:
# <h2>Hour Analysis</h2>
#     <style>
#         #sortable_table_581ee8a7 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_581ee8a7 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_581ee8a7 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_581ee8a7 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_581ee8a7 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_581ee8a7 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_581ee8a7 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_581ee8a7">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hour</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>10h</td>
#       <td>1:1</td>
#       <td>156</td>
#       <td>73</td>
#       <td>83</td>
#       <td>-10R</td>
#       <td>46.8%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>156</td>
#       <td>58</td>
#       <td>98</td>
#       <td>18R</td>
#       <td>37.2%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>156</td>
#       <td>43</td>
#       <td>113</td>
#       <td>16R</td>
#       <td>27.6%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>11h</td>
#       <td>1:1</td>
#       <td>136</td>
#       <td>52</td>
#       <td>84</td>
#       <td>-32R</td>
#       <td>38.2%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>136</td>
#       <td>44</td>
#       <td>92</td>
#       <td>-4R</td>
#       <td>32.4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>136</td>
#       <td>35</td>
#       <td>101</td>
#       <td>4R</td>
#       <td>25.7%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>104</td>
#       <td>21</td>
#       <td>83</td>
#       <td>-20R</td>
#       <td>20.2%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_581ee8a7');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
# <h2>Weekday Analysis</h2>
#     <style>
#         #sortable_table_6c84ac5a th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_6c84ac5a th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_6c84ac5a th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_6c84ac5a th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_6c84ac5a td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_6c84ac5a .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_6c84ac5a .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_6c84ac5a">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Weekday</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Monday</td>
#       <td>1:1</td>
#       <td>239</td>
#       <td>95</td>
#       <td>144</td>
#       <td>-49R</td>
#       <td>39.7%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>239</td>
#       <td>72</td>
#       <td>167</td>
#       <td>-23R</td>
#       <td>30.1%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>239</td>
#       <td>60</td>
#       <td>179</td>
#       <td>1R</td>
#       <td>25.1%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Tuesday</td>
#       <td>1:1</td>
#       <td>214</td>
#       <td>97</td>
#       <td>117</td>
#       <td>-20R</td>
#       <td>45.3%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>214</td>
#       <td>78</td>
#       <td>136</td>
#       <td>20R</td>
#       <td>36.4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>214</td>
#       <td>55</td>
#       <td>159</td>
#       <td>6R</td>
#       <td>25.7%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Wednesday</td>
#       <td>1:1</td>
#       <td>229</td>
#       <td>89</td>
#       <td>140</td>
#       <td>-51R</td>
#       <td>38.9%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>229</td>
#       <td>67</td>
#       <td>162</td>
#       <td>-28R</td>
#       <td>29.3%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>229</td>
#       <td>51</td>
#       <td>178</td>
#       <td>-25R</td>
#       <td>22.3%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Thursday</td>
#       <td>1:1</td>
#       <td>227</td>
#       <td>92</td>
#       <td>135</td>
#       <td>-43R</td>
#       <td>40.5%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>227</td>
#       <td>63</td>
#       <td>164</td>
#       <td>-38R</td>
#       <td>27.8%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>227</td>
#       <td>53</td>
#       <td>174</td>
#       <td>-15R</td>
#       <td>23.3%</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Friday</td>
#       <td>1:1</td>
#       <td>193</td>
#       <td>81</td>
#       <td>112</td>
#       <td>-31R</td>
#       <td>42.0%</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td></td>
#       <td>1:2</td>
#       <td>193</td>
#       <td>66</td>
#       <td>127</td>
#       <td>5R</td>
#       <td>34.2%</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td></td>
#       <td>1:3</td>
#       <td>193</td>
#       <td>53</td>
#       <td>140</td>
#       <td>19R</td>
#       <td>27.5%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_6c84ac5a');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
#                 });
#             }
#         }
#
#         // Apply initial green highlighting
#         applyWinRateHighlighting();
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
# <h2>30M Leg Analysis</h2>
#     <style>
#         #sortable_table_21877a62 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_21877a62 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_21877a62 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_21877a62 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_21877a62 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_21877a62 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_21877a62 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_21877a62">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>30M Leg</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Below H</td>
#       <td>1:1</td>
#       <td>198</td>
#       <td>88</td>
#       <td>110</td>
#       <td>-22R</td>
#       <td>44.4%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>198</td>
#       <td>71</td>
#       <td>127</td>
#       <td>15R</td>
#       <td>35.9%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>198</td>
#       <td>55</td>
#       <td>143</td>
#       <td>22R</td>
#       <td>27.8%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Below L</td>
#       <td>1:1</td>
#       <td>273</td>
#       <td>106</td>
#       <td>167</td>
#       <td>-61R</td>
#       <td>38.8%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>273</td>
#       <td>82</td>
#       <td>191</td>
#       <td>-27R</td>
#       <td>30.0%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>273</td>
#       <td>69</td>
#       <td>204</td>
#       <td>3R</td>
#       <td>25.3%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Above L</td>
#       <td>1:1</td>
#       <td>293</td>
#       <td>108</td>
#       <td>185</td>
#       <td>-77R</td>
#       <td>36.9%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>293</td>
#       <td>80</td>
#       <td>213</td>
#       <td>-53R</td>
#       <td>27.3%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>293</td>
#       <td>64</td>
#       <td>229</td>
#       <td>-37R</td>
#       <td>21.8%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Above H</td>
#       <td>1:1</td>
#       <td>338</td>
#       <td>152</td>
#       <td>186</td>
#       <td>-34R</td>
#       <td>45.0%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>338</td>
#       <td>113</td>
#       <td>225</td>
#       <td>1R</td>
#       <td>33.4%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>338</td>
#       <td>84</td>
#       <td>254</td>
#       <td>-2R</td>
#       <td>24.9%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_21877a62');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
#                 });
#             }
#         }
#
#         // Apply initial green highlighting
#         applyWinRateHighlighting();
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sort
# <h2>Stop Loss Distribution Analysis</h2>
#     <style>
#         #sortable_table_d4544acb th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_d4544acb th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_d4544acb th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_d4544acb th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_d4544acb td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_d4544acb .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_d4544acb .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_d4544acb">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SL Range</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>SL < 1</td>
#       <td>1:1</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>-5R</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>-5R</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#       <td>-5R</td>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1 ≤ SL < 5</td>
#       <td>1:1</td>
#       <td>524</td>
#       <td>170</td>
#       <td>354</td>
#       <td>-184R</td>
#       <td>32.4%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>524</td>
#       <td>146</td>
#       <td>378</td>
#       <td>-86R</td>
#       <td>27.9%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>524</td>
#       <td>118</td>
#       <td>406</td>
#       <td>-52R</td>
#       <td>22.5%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>5 ≤ SL < 10</td>
#       <td>1:1</td>
#       <td>451</td>
#       <td>223</td>
#       <td>228</td>
#       <td>-5R</td>
#       <td>49.4%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>451</td>
#       <td>164</td>
#       <td>287</td>
#       <td>41R</td>
#       <td>36.4%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>451</td>
#       <td>126</td>
#       <td>325</td>
#       <td>53R</td>
#       <td>27.9%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10 ≤ SL < 15</td>
#       <td>1:1</td>
#       <td>84</td>
#       <td>41</td>
#       <td>43</td>
#       <td>-2R</td>
#       <td>48.8%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>84</td>
#       <td>24</td>
#       <td>60</td>
#       <td>-12R</td>
#       <td>28.6%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>84</td>
#       <td>19</td>
#       <td>65</td>
#       <td>-8R</td>
#       <td>22.6%</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>SL ≥ 15</td>
#       <td>1:1</td>
#       <td>38</td>
#       <td>20</td>
#       <td>18</td>
#       <td>2R</td>
#       <td>52.6%</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td></td>
#       <td>1:2</td>
#       <td>38</td>
#       <td>12</td>
#       <td>26</td>
#       <td>-2R</td>
#       <td>31.6%</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td></td>
#       <td>1:3</td>
#       <td>38</td>
#       <td>9</td>
#       <td>29</td>
#       <td>-2R</td>
#       <td>23.7%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_d4544acb');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
#                 });
#             }
#         }
#
#         // Apply initial green highlighting
#         applyWinRateHighlighting();
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[col
# <h2>Take Profit Distribution Analysis</h2>
#     <style>
#         #sortable_table_4eb252ac th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_4eb252ac th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_4eb252ac th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_4eb252ac th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_4eb252ac td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_4eb252ac .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_4eb252ac .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_4eb252ac">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TP Range</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>TP < 10</td>
#       <td>1:1</td>
#       <td>90</td>
#       <td>68</td>
#       <td>22</td>
#       <td>75.6%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>90</td>
#       <td>21</td>
#       <td>69</td>
#       <td>23.3%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>90</td>
#       <td>5</td>
#       <td>85</td>
#       <td>5.6%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10 ≤ TP < 20</td>
#       <td>1:1</td>
#       <td>156</td>
#       <td>140</td>
#       <td>16</td>
#       <td>89.7%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>156</td>
#       <td>95</td>
#       <td>61</td>
#       <td>60.9%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>156</td>
#       <td>54</td>
#       <td>102</td>
#       <td>34.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>20 ≤ TP < 30</td>
#       <td>1:1</td>
#       <td>84</td>
#       <td>80</td>
#       <td>4</td>
#       <td>95.2%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td></td>
#       <td>1:2</td>
#       <td>84</td>
#       <td>67</td>
#       <td>17</td>
#       <td>79.8%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td></td>
#       <td>1:3</td>
#       <td>84</td>
#       <td>57</td>
#       <td>27</td>
#       <td>67.9%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>TP ≥ 30</td>
#       <td>1:1</td>
#       <td>170</td>
#       <td>166</td>
#       <td>4</td>
#       <td>97.6%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>1:2</td>
#       <td>170</td>
#       <td>163</td>
#       <td>7</td>
#       <td>95.9%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td></td>
#       <td>1:3</td>
#       <td>170</td>
#       <td>156</td>
#       <td>14</td>
#       <td>91.8%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_4eb252ac');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if (rrrValue === '1:1' && winPercentValue > 50) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:2' && winPercentValue > 33) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             } else if (rrrValue === '1:3' && winPercentValue > 25) {
#                                 winPercentCell.classList.add('win-rate-green');
#                             }
#                         }
#                     }
#                 });
#             }
#         }
#
#         // Apply initial green highlighting
#         applyWinRateHighlighting();
#
#         // Store the currently highlighted column index
#         let currentHighlightIndex = -1;
#         const initialHighlightColumn = '';
#
#         // Find the initial highlight column index
#         if (initialHighlightColumn) {
#             const headerRow = table.querySelector('thead tr');
#             currentHighlightIndex = Array.from(headerRow.children).findIndex(th =>
#                 th.textContent.trim() === initialHighlightColumn
#             );
#         }
#
#         // Function to apply highlighting to a specific column
#         function applyHighlighting(columnIndex) {
#             // Clear all existing highlights
#             headers.forEach((header, idx) => {
#                 header.style.color = '';
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = row.querySelectorAll('td');
#                     if (cells[idx]) {
#                         cells[idx].style.color = '';
#                         cells[idx].style.fontWeight = '';
#                     }
#                 });
#             });
#
#             // Apply new highlight if valid column
#             if (columnIndex !== -1 && columnIndex < headers.length) {
#                 // Highlight header
#                 headers[columnIndex].style.color = 'green';
#
#                 currentHighlightIndex = columnIndex;
#             }
#         }
#
#         // Mark sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (headers[colIndex]) {
#                 headers[colIndex].classList.add('sortable');
#             }
#         });
#
#         // Apply initial highlighting
#         applyHighlighting(currentHighlightIndex);
#
#         // Set initial sort state for Edge column (data is pre-sorted descending by Edge)
#         if (currentHighlightIndex !== -1 && sortableColumns.includes(currentHighlightIndex)) {
#             headers[currentHighlightIndex].classList.add('sorted-desc');
#         }
#
#         // Add click handlers to sortable columns
#         sortableColumns.forEach(colIndex => {
#             if (!headers[colIndex]) return;
#
#             headers[colIndex].addEventListener('click', function() {
#                 const rows = Array.from(tbody.querySelectorAll('tr'));
#                 const co
# <h2>Pullback Analysis</h2>
#     <style>
#         #sortable_table_20502c65 th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_20502c65 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_20502c65 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_20502c65 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_20502c65 td:first-child {
#             font-weight: bold;
#             width: 250px;
#         }
#
#         #sortable_table_20502c65 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_20502c65 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_20502c65">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>RRR</th>
#       <th>Total Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Outcome</th>
#       <th>Win %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>No Pullback</td>
#       <td>1:1</td>
#       <td>1102</td>
#       <td>454</td>
#       <td>648</td>
#       <td>-194R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1102</td>
#       <td>346</td>
#       <td>756</td>
#       <td>-64R</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1102</td>
#       <td>272</td>
#       <td>830</td>
#       <td>-14R</td>
#       <td>24.7%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.5 pip Pullback</td>
#       <td>1:1</td>
#       <td>1090</td>
#       <td>449</td>
#       <td>641</td>
#       <td>-192R</td>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>1:2</td>
#       <td>1090</td>
#       <td>342</td>
#       <td>748</td>
#       <td>-64R</td>
#       <td>31.4%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>1:3</td>
#       <td>1090</td>
#       <td>268</td>
#       <td>822</td>
#       <td>-18R</td>
#       <td>24.6%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1 pip Pullback</td>
#       <td>1:1</td>
#       <td>974</td>
#       <td>342</td>
#       <td>632</td>
#       <td>-290R</td>
#       <td>35.1%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <
td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td>1:3</td>
#       <td>736</td>
#       <td>88</td>
#       <td>648</td>
#       <td>-384R</td>
#       <td>12.0%</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_20502c65');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [6];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
# ...
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_b4594676 th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_b4594676 th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_b4594676 th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_b4594676 td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_b4594676 .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_b4594676 .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_b4594676">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#       <th>Trades Required</th>
#       <th>Drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>CH + News > 2hrs</td>
#       <td>1:3</td>
#       <td>100</td>
#       <td>30</td>
#       <td>70</td>
#       <td>30.0%</td>
#       <td>5.0%</td>
#       <td>20R</td>
#       <td>5.0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>30M Trend + News > 2hrs</td>
#       <td>1:3</td>
#       <td>185</td>
#       <td>51</td>
#       <td>134</td>
#       <td>27.6%</td>
#       <td>2.6%</td>
#       <td>19R</td>
#       <td>9.7</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>30M Trend + BOS</td>
#       <td>1:3</td>
#       <td>466</td>
#       <td>128</td>
#       <td>338</td>
#       <td>27.5%</td>
#       <td>2.5%</td>
#       <td>46R</td>
#       <td>10.1</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>30M Trend + SL < 10</td>
#       <td>1:3</td>
#       <td>550</td>
#       <td>148</td>
#       <td>402</td>
#       <td>26.9%</td>
#       <td>1.9%</td>
#       <td>42R</td>
#       <td>13.1</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>EMA + No News</td>
#       <td>1:3</td>
#       <td>419</td>
#       <td>105</td>
#       <td>314</td>
#       <td>25.1%</td>
#       <td>0.1%</td>
#       <td>1R</td>
#       <td>419.0</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>
#
#     <script>
#     (function() {
#         const table = document.getElementById('sortable_table_b4594676');
#         if (!table) return;
#
#         const tbody = table.querySelector('tbody');
#         const headers = table.querySelectorAll('thead th');
#         const sortableColumns = [7, 8, 9, 10];
#
#         // Find the columns for RRR and Win %
#         const headerRow = table.querySelector('thead tr');
#         const headerCells = Array.from(headerRow.children);
#         const rrrColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'RRR');
#         const winPercentColumnIndex = headerCells.findIndex(th => th.textContent.trim() === 'Win %');
#
#         // Function to apply green highlighting to Win % cells based on RRR value
#         function applyWinRateHighlighting() {
#             if (rrrColumnIndex !== -1 && winPercentColumnIndex !== -1) {
#                 const rows = tbody.querySelectorAll('tr');
#                 rows.forEach(row => {
#                     const cells = Array.from(row.querySelectorAll('td'));
#
#                     // Account for the fact that header includes index column but we need to match with td elements
#                     // The headerCells index includes the index column (th), but cells are only td elements
#                     // So we need to subtract 1 from the header index to get the td index
#                     const rrrCell = cells[rrrColumnIndex - 1];
#                     const winPercentCell = cells[winPercentColumnIndex - 1];
#
#                     if (rrrCell && winPercentCell) {
#                         const rrrValue = rrrCell.textContent.trim();
#                         const winPercentText = winPercentCell.textContent.trim();
#                         const winPercentValue = parseFloat(winPercentText.replace('%', ''));
#
#                         // Remove existing green class first
#                         winPercentCell.classList.remove('win-rate-green');
#
#                         if (!isNaN(winPercentValue)) {
#                             // Check thresholds based on RRR
#                             if
# <h2>Triple Setup Strategies</h2>
#     <style>
#         #sortable_table_31dc8f6f th.sortable {
#             cursor: pointer;
#             user-select: none;
#         }
#
#         #sortable_table_31dc8f6f th.sortable::after {
#             content: ' ⇅';
#             color: #999;
#             font-size: 12px;
#         }
#
#         #sortable_table_31dc8f6f th.sorted-asc::after {
#             content: ' ↑';
#             color: #999;
#         }
#
#         #sortable_table_31dc8f6f th.sorted-desc::after {
#             content: ' ↓';
#             color: #999;
#         }
#
#         #sortable_table_31dc8f6f td:first-child {
#             font-weight: bold;
#             width: 300px;
#         }
#
#         #sortable_table_31dc8f6f .highlight-column {
#             color: green !important;
#             font-weight: bold;
#         }
#
#         #sortable_table_31dc8f6f .win-rate-green {
#             color: #2ecc71 !important;
#             font-weight: bold;
#         }
#     </style>
#
#     <table border="1" class="dataframe sortable-table" id="sortable_table_31dc8f6f">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strategy</th>
#       <th>RRR</th>
#       <th>Trades</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Win Rate</th>
#       <th>Edge</th>
#       <th>Outcome</th>
#       <th>Trades Required</th>
#       <th>Drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>30M Trend + 5 < SL < 10</td>
#       <td>1:2</td>
#       <td>243</td>
#       <td>93</td>
#       <td>150</td>
#       <td>38.3%</td>
#       <td>5.0%</td>
#       <td>36R</td>
#       <td>6.8</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>30M Trend + 5 < SL < 10</td>
#       <td>1:1</td>
#       <td>243</td>
#       <td>126</td>
#       <td>117</td>
#       <td>51.9%</td>
#       <td>1.9%</td>
#       <td>9R</td>
#       <td>27.0</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>30M Trend + 5 < SL < 15</td>
#       <td>1:1</td>
#       <td>292</td>
#       <td>150</td>
#       <td>142</td>
#       <td>51.4%</td>
#       <td>1.4%</td>
#       <td>8R</td>
#       <td>36.5</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>EMA + BOS + SL < 10 + No News</td>
#       <td>1:2</td>
#       <td>312</td>
#       <td>108</td>
#       <td>204</td>
#       <td>34.6%</td>
#       <td>1.3%</td>
#       <td>12R</td>
#       <td>26.0</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>EMA + BOS + SL ≤ 15</td>
#       <td>1:3</td>
#       <td>565</td>
#       <td>148</td>
#       <td>417</td>
#       <td>26.2%</td>
#       <td>1.2%</td>
#       <td>27R</td>
#       <td>20.9</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>EMA + BOS + No News</td>
#       <td>1:3</td>
#       <td>352</td>
#       <td>92</td>
#       <td>260</td>
#       <td>26.1%</td>
#       <td>1.1%</td>
#       <td>16R</td>
#       <td>22.0</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>EMA + BOS + 30M Trend</td>
#       <td>1:2</td>
#       <td>409</td>
#       <td>140</td>
#       <td>269</td>
#       <td>34.2%</td>
#       <td>0.9%</td>
#       <td>11R</td>
#       <td>37.2</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>30M Trend + EMA + BOS</td>
#       <td>1:2</td>
#       <td>409</td>
#       <td>140</td>
#       <td>269</td>
#       <td>34.2%</td>
#       <td>0.9%</td>
#       <td>11R</td>
#       <td>37.2</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>EMA + BOS + No News or News > 2hrs</td>
#       <td>1:3</td>
#       <td>514</td>
#       <td>133</td>
#       <td>381</td>
#       <td>25.9%</td>
#       <td>0.9%</td>
#       <td>18R</td>
#       <td>28.6</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>30M Trend + EMA + SL < 10</td>
#       <td>1:2</td>
#       <td>423</td>
#       <td>144</td>
#       <td>279</td>
#       <td>34.0%</td>
#       <td>0.7%</td>
#       <td>9R</td>
#       <td>47.0</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>EMA + BOS + SL < 10 + News > 2hrs</td>
#       <td>1:3</td>
#       <td>149</td>
#       <td>38</td>
#       <td>111</td>
#       <td>25.5%</td>
#       <td>0.5%</td>
#       <td>3R</td>
#       <td>49.7</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>EMA + BOS + News > 2hrs</td>
#       <td>1:3</td>
#       <td>162</td>
#       <td>41</td>
#       <td>121</td>
#       <td>25.3%</td>
#       <td>0.3%</td>
#       <td>2R</td>
#       <td>81.0</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>EMA + BOS + SL ≤ 5</td>
#       <td>1:3</td>
#       <td>301</td>
#       <td>76</td>
#       <td>225</td>
#       <td>25.2%</td>

# %%
from utils import display_strategy_trade_details

display_strategy_trade_details(df)
# Out:
# <h2>Strategy Trade Details</h2>
# <p>Select a profitable strategy to view all its trades with profitability indicators.</p>
# HBox(children=(Dropdown(description='Strategy:', layout=Layout(width='600px'), options=(('Select a strategy...…
# Output()

# %%
# from utils import export_strategy_trades_to_csv

# export_strategy_trades_to_csv(df, strategy_name="EMA + BOS", rrr_ratio=3, output_file="ema_bos_trades.csv")
